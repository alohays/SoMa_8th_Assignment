# %% [markdown]
# # 8기 과제 - 딥러닝 기반 상품 카테고리 자동 분류 서버

# %% [markdown]
# ## 과제 개요
# * 출제자 : 남상협 멘토 (justin@buzzni.com) / 버즈니 (http://buzzni.com) 대표
# * 배경 : 카테고리 분류 엔진은 실제로 많은 서비스에서 사용되는 중요한 기계학습 기술이다. 본 과제의 주제는 버즈니 개발 인턴이자 마에스트로 6기 멘티가 아래와 나와 있는 기본 분류 모델을 기반으로 deep learning 기반의 feature 를 더해서 고도화된 분류 엔진을 만들어서 2016 한국 정보과학회 논문으로도 제출 했던 주제이다. 기계학습에 대한 학습과, 실용성 두가지 측면에서 모두 도움이 될 것으로 보인다.

# %% [markdown]
# ## 과제 목표
# * 입력 : 상품명, 상품 이미지
# * 출력 : 카테고리
# * 목표 : 가장 높은 정확도로 분류를 하는 분류 엔진을 개발

# %% [markdown]
# ## 평가 항목
# * 성능평가 (100%)
#
# ## 제출 항목
# * 채점 서버에 자신이 분류한 class id 리스트를 파라미터로 넣어서 호출한다.
# * name - 자신의 이름을 넣는다. 실제 점수판에는 공개가 안됨, 추후 평가시에 일치하는 이름의 멘티 점수로 사용함. 요청한 평가 중에서 가장 높은 점수의 평가 점수로 업데이트됨.
# * nickname - 점수판에 공개되는 이름, 자신의 이름으로 해도 되고, 닉네임으로 해도 됨. 구분을 위해서 사용하는 feature(text, textimage) 와 알고리즘 (svm, cnn) 등을 닉네임 뒤에 붙여준다.
# * pred_list - 분류한 카테고리 id 리스트를 , 로 묶은 데이터
# * 평가 점수가 반환된다. - precision, 높을 수록 좋다. 두가지 방법 각각 50%씩 점수 반영
# * mode - 'test' 로 호출하면 웹으로 순위가 공개되는 테스트 평가를 수행하고 결과 점수가 반환된다. 해당 결과 점수는 http://eval.buzzni.net:20002/score 에서 확인 가능함. 실제 성적 평가는 'eval' 로 평가용 데이터로 호출하면 된다. 이때는 점수가 반환되거나, 웹 점수 보드에도 나오지 않는다.
# * 너무 자주 평가를 요청하기 보다, 가급적 자체적으로 평가 해서, 괜찮게 나올때 요청하길 권장
# ```python
# import requests
# name='test1'
# nickname='test1_text_svm'
# mode='test' #'eval' 을 실제 성적 평가용. 분류 점수 반환 안됨.
# param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list)),
#          'name':name,'nickname':nickname,"mode":mode}
# d = requests.post('http://eval.buzzni.net:20001/eval',data=param)
# print (d.json())
#          ```

# %% [markdown]
# ## 성능 향상 포인트
# * http://localhost:8000/notebooks/maestro8_deeplearning_product_classifier.ipynb 이 노트북에 있는 딥러닝 기반의 분류기로 분류할 경우에 더 높은 성능을 낼 수 있어서 유리함
# * 아래의 방법들은 하나의 예이고, 아래에 나와 있지 않은 다양한 방법들도 가능함.
# * 전처리
#  * 오픈된 형태소 분석기(예 - konlpy) 를 써서, 단어 띄어쓰기를 의미 단위로 띄어서 학습하기
#  * bigram, unigram, trigram 등 단어 feature 를 더 다양하게 추가하기
# * 딥러닝
#  * embedding weight 를 random 이 아닌 학습된 값을 사용하기 (https://radimrehurek.com/gensim/models/word2vec.html)
#  * 이미지 feature 를 CNN으로 추출할때 더 성능이 좋은 모델 사용하기 (예제로 준 데이터는 mobilenet 으로 성능보다 속도 위주로 된 모델)
#  * 다양한 파라미터(hyper parameter) 로 실험 해보기
# * 피쳐 조합
#  * 이미지 feature 와 text feature 를 합치는 부분 잘하기

# %% [markdown]
# ## 평가 점수 서버
# * 현재 평가 순위를 json 형태로 반환한다.
# * 여러번 호출했을때는 가장 높은 점수로 업데이트 한다.
#  * http://eval.buzzni.net:20002/score
# * 실제 점수는

# %%
import sys
from sklearn.externals import  joblib
from sklearn.grid_search import GridSearchCV
from sklearn.svm import  LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import  TfidfVectorizer,CountVectorizer
import os
import numpy as np
import string
from keras import backend
from keras.layers import Dense, Input, Lambda, LSTM, TimeDistributed
from keras.layers.merge import concatenate
from keras.layers.embeddings import Embedding
from keras.models import Model
# Out:
# /usr/local/lib/python3.4/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.4/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# Using TensorFlow backend.

# %% [markdown]
# ### 파일에서 학습 데이터를 읽는다.

# %%
import json

# %%
x_text_list = []
y_text_list = []
enc = sys.getdefaultencoding()
with open("refined_category_dataset.dat",encoding=enc) as fin:
    for line in fin.readlines():
#         print (line)
        info = json.loads(line.strip())
        x_text_list.append((info['pid'],info['name']))
        y_text_list.append(info['cate'])

# %%
# joblib.dump(y_name_id_dict,"y_name_id_dict.dat")

# %% [markdown]
# ### text 형식으로 되어 있는 카테고리 명을 숫자 id 형태로 변환한다.

# %%
y_name_id_dict = joblib.load("y_name_id_dict.dat")

# %%
print(y_name_id_dict)
# Out:
# {'뷰티': 0, '스포츠/레저': 9, '건강': 7, '자동차/공구': 1, '출산/육아': 16, '도서/문구': 8, '가구/인테리어': 11, '식품': 6, '여행/e쿠폰': 15, '디지털': 10, '반려동물': 4, '컴퓨터': 3, '잡화': 14, '취미': 5, '의류': 2, '가전': 12, '생필품/주방': 13}

# %%
# y_name_set = set(y_text_list)
# y_name_id_dict = dict(zip(y_name_set, range(len(y_name_set))))
# print(y_name_id_dict.items())
# y_id_name_dict = dict(zip(range(len(y_name_set)),y_name_set))
y_id_list = [y_name_id_dict[x] for x in y_text_list]

# %% [markdown]
# ### text 형태로 되어 있는 상품명을 각 단어 id 형태로 변환한다.

# %%
x_text_list[:3]
# Out:
# [('1234621373', '#MD추천정품# 심플베드 엘레강스 고급형 접이식침대 더블사이즈115cm/수동/등받이6단으로 원하는각도조절'),
#  ('1543513007', '(9731200) 소형제도판 (S) 661 A3'),
#  ('1546650266', '(AGCRIP 웨빙 포켓조끼 빅사이즈 조끼 MK321_324 아웃')]

# %%
tmp_list = list(map(lambda i:i[1],x_text_list))
tmp_list
# Out:
# ['#MD추천정품# 심플베드 엘레강스 고급형 접이식침대 더블사이즈115cm/수동/등받이6단으로 원하는각도조절',
#  '(9731200) 소형제도판 (S) 661 A3',
#  '(AGCRIP 웨빙 포켓조끼 빅사이즈 조끼 MK321_324 아웃',
#  '(ATK아텍스 전동접이식침대(BE556) 전동침대 간병용침',
#  '(MST플래그 메세지 캔들 마더 향초 양초캔들 캔들선물 아로마캔들 향초캔들',
#  '(광일체어) 스카치A형 3인 등무 장의자',
#  '(광일체어) 스파고아우드 2인 등유 로비용장의자',
#  '(라움스튜디오)스크류 블랙봉 (일반-2.5cm) / 블랙 커튼봉/ 25mm / 일반봉 / 커튼봉 / 블랙',
#  '(모슬리메모리즈) 산토리니 브리즈 (중) 모슬리메모리즈 아로마캔들 디퓨저 소이캔들 소이왁스',
#  '(무료배송)양키캔들 악세사리 윅디퍼 심지가위 라이터',
#  '(시그마) LED 원형 센서등 15w - 계단등/현관등',
#  '(아텍스 접이식침대(BG542) +온열매트) 이동식침대/기능성침대/간이침대',
#  '(인테리어 소품) 빈티지 수납함의자 에펠탑 수납의자',
#  '(자동에어 배게)목쿠션 등산용품 아웃도어용품 야외캠핑용품 산악용품 등산장비 캠핑 캠핑용품 아웃도어/',
#  '(추천) 코스모스슬림오픈비누각2/ 빨래비누통 비누통 기타욕실용품 고급욕실용품 주방욕실용품 비누각 세수',
#  '(추천)미린 2인용 장의자 의자 로비용의자 휴게실의자/ 대기용장의자 인테리어장의자 장의자 심플의자 가구',
#  '(추천)유럽풍인형-강아지와나들이(N111) 장식도자기인형 인테리어소품 엔틱소품 집들이 데코/ 도자기인형',
#  '(한양) 혼수용10호 (바느질 실 10칼라) / 재봉실 (003',
#  '(히트가구)600입식컴퓨터책상 입식책상 컴퓨터책상 서재책상 입식책상 컴퓨터책상 책상 다용도책상',
#  '(히트디자인)미니좌식_300협탁 컴퓨터책상 책상 미니',
#  '/CO 압축 욕실 스텐레스 수건걸이 3단/ 일자선반 욕실',
#  '1200M [색잇] SACK IT RETROit Canvas 라운지체어 빈백   Sand',
#  '1200M [오르골하우스] 행복한 파리여행 오르골  멜로디 선택 가능',
#  '1200M [제이밀크] 퐁퐁바다 키재기 기성형 족자봉 스티커 포함',
#  '1200M [투에스벅] 핑크소녀 크리스마스 장식 드림캐쳐',
#  '1200M [퓨어코튼] 대폭 데일리미니체크 라미방수식탁보 2인s 90cm',
#  '120cm 카니발골드 화이트 풀세트 트리 -실내장식트리',
#  '120cm 털옷 입은 롱다리 산타인형 대형 산타',
#  '12촌탁상사진액자(10개) 상장액자 사진액자 웨딩액자',
#  '1300K [까사라이트] 메종벽등 15w삼파장볼구',
#  '1300K [데일리홈] 블랙 스트라이프 방수식탁보 8인260cm',
#  '1300K [라임라잇] 루나하임 ReFresh 바디필로우',
#  '1300K [스포이드] 마이크로화이버 쿠션솜 50x50  세탁가능',
#  '1300K [주조밍] 주조밍 린넨 헤링본블루 식탁보 6인용',
#  '1300K [퓨어코튼] 에이미 베이직 체크 라미네이트 방수 식탁보 2인용100x100',
#  '150cm 엔젤블루 최고급 리얼 솔잎트리(접이식) 풀세트',
#  '18P 가정용 바늘세트 가정용바늘 바늘세트 집바늘 휴',
#  '210cm 전나무 혼합 트리',
#  '25mm 크레이브볼 커튼봉/540cm/18자/안테나형간편조절/2color',
#  '3000PS 황토흙 흙쇼파 흙카우치',
#  '35mm 심플 라운드 커튼봉',
#  '3단 필라 라탄 파티션 칸막이 가리개 블라인드 세칸',
#  '40-40cm 로라쿠션 (자체제작 핸드메이드) 솜포함 쇼파쿠션 빵빵한쿠션 예쁜사각쿠션 다용도쿠션 가정용쿠션',
#  '45T PVC 사무실용 원톤 투톤 유리 우드 파티션 주문제작 국산정품 최고의 퀄리티와 경제적인 가격',
#  '4단교구장 오크/유치원교구장 장난감정리장 사무용품',
#  '50p 둥근머리 나사(14mm) 철물 볼트나사 피스 철물류',
#  '60cm 핑크 반짝이 트리',
#  '7단가로등 분수대 장식품 분수대소품 인테리어분수 분',
#  'B3-자석액자 안내판/사무실현판/종합안내판/아크릴현판/실내현판/아크릴문패/사무실문패/아크릴입간판',
#  'D 진핑크 반짝이 산타모자(40cm×30cm)이벤트 행사',
#  'DAYON(데이온) 프리미엄 거위털 구스베개 50x70㎝',
#  'DK2 페러스 서랍함 18호 3단 색상랜덤발송[D490315] 데스크용품_서랍함 수납함 데스크용품',
#  'DRETEC 드레텍 CL-117 전자 계산기 학생 학습 공부 학원 요리 연구 계측 측정 주방 업다운 타이머 스톱워치',
#  'EX 체어/CEO 체어/Best 5선정/중역용의자/사무용의자/임원의자/2중럭킹',
#  'FINNVARD 선반트레슬다리, 화이트 701.676.33',
#  'Fill&DECO 국산 알루미늄 베네시안 블라인드',
#  'GE)삼파장 형광등 (18W-11주광색) M763510',
#  'GRUNDTAL 수건레일, 스테인리스 80cm 401.818.19',
#  'H-하늘정원 (244471) 암막 실사 롤블라인드 125X185cm/ 앙상블',
#  'HAPPYYOGA 正品 편백 아이필로우180g 수면용품 수면',
#  'IKEA VITTEN Rug, high pile, white 401.664.80',
#  'J-로키 콤비블라인드 (95X240cm) 2가지색상',
#  'JM 별 램프 아동용 산타모자(33cm×25cm) 산타의상',
#  'KD-f 717 [카페의자/인테리어의자/보조의자/식탁의자/디자인의자/가벼운의자]',
#  'KJH-082/083/093/KJ블루칩/돈풍기/곱창난로전문점/특허상품/강력한화력/이동식바퀴장착/양면난방가능/원적외선난방기/신진',
#  'LED 무드등 조명 테이블 3D램프 3D입체램프 취침등',
#  'LED 휴대용 독서등 돋보기 북라이트 패널',
#  'LG Z:IN 친환경식물성수지벽지 지아프레쉬/소프트무지/라이트그레이 ZEA517-2/1롤',
#  'LG Z:in 고급직물실크벽지[패브릭]비엔나실크/파스텔핑크 T1017-1/ 1롤[5평]',
#  'LG인테리어필름-NW018(티크)/친환경, 방염시트',
#  'LOVE 알파벳몰딩 몰딩 데코 소품 집들이 선물 인테리',
#  'MDC-161 벽시계 고급벽시계 벽장식 엔틱벽시계 모던벽시계 시계',
#  'MST () 디지털 타이머)/다용도타이머/카운트다운/스톱워치/타이머/디지털타이머',
#  'O다량구매 차등가격O 4×6 탁상용 2중 접이식 액자/액자/액자/앨범/판촉물/교회/태권도/학교/유치원 졸업선',
#  'O다량구매 차등가격O 베이직 아크릴 화장품 정리대/정리대/정리대/정리함/보관함/코너장/욕실정리대/판촉물',
#  'PJ 두루마리휴지케이스 철제 롤휴지통 롤휴지커버 롤',
#  'Portofino Pot Mitt 오븐장갑 메모꽂이-울스터위버스',
#  'RUUSA 애쉬원목 고급도장 가구! 거실장/협탁/소파테이블/거실장 세트/거실가구',
#  'SK 인테리어필름 GE-891',
#  'TOYO 펠트(접착-녹색-S304-10매입) 토요펠트 문구펠트',
#  'Tf 다우니 퍼퓸 화이트 2L 클래식향 2개/유연제/b',
#  'WHI판촉물 생활용품 크록스 다용도 강력접착제 30ml (',
#  'WPS053,선글라스착용금지,No Sunglass,금지표지판,간판,표지판,실내간판,표시판,안내판,경고판,표찰',
#  'W_ 남원유전 직사각밥상 2인용 차상 사각밥상 밥상 주',
#  'W_ 움직이는 메모리폼 마우스 손목쿠션 마우스패드 손',
#  '[1358K-꾸밈] ij127-고기잡는 소년과 강아지/글라스시트지/소년/강아지/바다/…5',
#  '[1358k] cp204-산토리노의아침_유리문시트지',
#  '[1358k] cs101-뮤직 빌리지_글라스_글라스시트지',
#  '[2.5M /접착식 단열벽지]아이방도 안심 시공',
#  '[2개묶음판매]할로겐램프/오스람/XENOPHOT 64653 HLX',
#  '[3M]마루보호형 패드 767',
#  '[3연동도어/중문/현관] 메타세콰이어 (데코글라스)',
#  '[BC카드10%] 서일본 JR-WEST 간사이 호쿠리쿠 패스(성인/아동/) 7일',
#  '[BEAT] 시간배분 연습용 수능타이머 Ready/시간타이머',
#  '[CHAIR B] 체어B 시스템 의자 / 책상 / 사무용 / 사무실 / 인테리어 / 컴퓨터 / 학생용 D237C(D237C)',
#  '[GL]모스 LED에디슨볼램프(E26/G80)',
#  '[GM데코] cs058-커피패턴 현관문시트지_현관문방문시트지',
#  '[GOODZZIM] 동물나라 다용도 담요(100cm×75cm)',
#  '[GOODZZIM] 캐니멀 인형의자-울리',
#  '[LG하우시스] 고급 옥수수재료 바닥재/마루 지아마루',
#  '[NICE FEEL] 아도니스 피그먼트 차렵이불(S)',
#  '[SASA][사사가구] 도담자작 편수책상 [배송비별도]',
#  '[Sigill] 수중용접착/수중실리콘/SIMPSeal-640/선박용',
#  '[classic fabric]폴란드산 구스다운 베개 솜털95%,순면80수,알러지방지원단,1000g',
#  '[hdp] 공간활용 사각형 4단 선반 4단선반 다용도선반 사각형선반 미니선반 메탈선반',
#  '[가구랜드]와이즈 고급 인조가죽 리클라이너',
#  '[까미엘]NEW 제니아 1800 스마트 서랍렌지대(PM_CJ0062)',
#  '[까사펠리체]그린플라워커튼 대형풀세트(겉커튼,속커튼,부자재)',
#  '[꼬꼬마로] (포켓몬스터) XY 쿠션-메타몽 A 40cm',
#  '[꾸밈] cp150-봄이왔어요_현관문방문시트지',
#  '[나라쇼핑] 쿨매트 대형 아이스매트 여름매트 시원한',
#  '[나무뜰] 레이첼 400 미니수납장 WL006',
#  '[나무뜰] 마가렛 LPM 2단서랍장 WL030',
#  '[누비유통]소프트 퀼트 매트(160X210) 소프트퀼트매트 면매트 매트 면카페트 카페트 퀼트매트 퀼트 빠른배',
#  '[다인패브릭] 거위털 이불솜 프리미엄 알레르겐 퀸 800g',
#  '[대박 SALE! 사은품증정] 온가족이 함께 그리는 DIY 명화그리기 유화그리기 캔버스 페인팅 퍼즐 액자 물감',
#  '[더 러그] 발염 라라 극세사 러그 카페트 200X270 +욕실발매트',
#  '[더리드 (THE LEAD)]벤더 투서랍 장롱9R[갤러리아]',
#  '[더젠] 럭셔리프리미엄 가죽철재책상(본체책상/고급가죽상판포함)',
#  '[더프리그]핸드메이드 제품  호박쿠션 / 솜포함 - 3color',
#  '[도모디자인] 아이린 4인 대리석 식탁세트 B형 (의자4개)',
#  '[동서가구][동서가구]CP 3인 소파베드 DF6336J6[갤러리아]',
#  '[득템나라]자석 부착식 액자 AP-B4 벽걸이형 아크릴커버형',
#  '[디자이너스룸]모던라운지 빈켈 4인 가죽 소파 (스툴별도)',
#  '[럭스라이팅] 크롬 3등 샹들리에',
#  '[레인보우하우스] 비비드 말 암막커튼 네이비 S 1장',
#  '[레인보우하우스][레인보우하우스] 꽃 쉬폰커튼 핑크꽃 M 1장[갤러리아]',
#  '[룸앤홈]노르딕 다용도 테이블 /사각 /원형티테이블 /쇼파협탁',
#  '[르헤브] 데이지 이중 편백베개(편백속포함)',
#  '[리진]어린왕자 피치스킨 홑겹 매트리스커버(SS)',
#  '[리피트리(Leafytree)]아카이 편백나무원목 2100 거실장 세트',
#  '[마레앤코] 컨티넘 블랙 2400 거실장 MRSK008',
#  '[마틴싯봉리빙] 쿠션솜 50X50(85WM330_31)',
#  '[매니퀸] 레더(천연소가죽) 마우스패드',
#  '[모노데코]매직 스마트 책상서랍세트',
#  '[모던하우스]밍크스완 면기모 패드 115*205',
#  '[무료배송]네모스툴(GM)              스툴의자/화장대의자/보조의자/간이의자/인테리어의자/매장의자',
#  '[물에빠진벽지]셀프도배(이마트)_무지민트_풀바른벽지',
#  '[미르엔]큐디 부엉 도자기 화병(PO)',
#  '[밀크 라텍스] 굴곡지압 베개/굴곡XL/100% 천연라텍스',
#  '[바보사랑][맘투비]순면방수패드/방수요_칵투스[무료배송]',
#  '[바보사랑][이소품]모넬리 폴딩 협탁[무료배송]',
#  '[바보사랑][포메리트]2단 서랍화장대[무료배송]',
#  '[바보사랑][포메리트]미니화장대[무료배송]',
#  '[바비루사] 하이스트바란스',
#  '[박씨상방] (2종)나전 한지 필함+명함함(보매팔각)/선물로좋은나전칠기',
#  '[박씨상방] (2종)선물용 고급나전필함+중지갑세트(대한민국)',
#  '[박씨상방] 명품 송월 순 납작투각 행꼬',
#  '[밸런스가구][밸런스가구]이네스 아카시아 원목 4인용 식탁 벤치세트[갤러리아]',
#  '[베드앤데코]스칼렛 베개커버',
#  '[베이직팩토리]체르카 1600 H형 책상세트(서랍별도)',
#  '[벨라이프] 모던디어 1장 커튼',
#  '[비앙스]인우드 원목 4단 800서랍장',
#  '[비앙코네로]Snow Horse DTP쿠션(60X60-솜포함)',
#  '[쁘리엘르]폴라 DTP 극세사 카페트 100x150',
#  '[상일리베가구]소나무 원목 테이블 1000',
#  '[세인트스코트]메모리폼 베개&밤부소재 커버 1+1(30x5',
#  '[수스토어]YED비엔 라텍스 S경추형베개 라텍스베게 라텍스 베개 침구류 베게 라텍스베개 빠른배송',
#  '[수지씨앤엘] 유럽 캐노피 모기장 아이보리 SZ0053',
#  '[쉬즈홈] 모던라이프 DTP 선풍기커버',
#  '[슈에뜨룸]유아순면차렵이불/낮잠이불/어린이집이불',
#  '[스텐3단 대형]S9754 주방카트 식당카트 식당카 서빙',
#  '[신세계몰]루튼침대 천연 라텍스 매트리스 수퍼싱글 7.5cm/밀도85kg/7존라텍스',
#  '[신세계몰]호텔식 제노바 LED 프리미엄 평상형침대K-독립쿠션매트리스K',
#  '[신한 자연림 세계최초 천연벽지] 33312-1 딘 화이트',
#  '[아망떼] 폴라곤베어 극세사 카페트 145x200',
#  '[아트박스 POOM/로즈마리DIY] ECO털실로 만드는 멍석뜨기 목도리DIY',
#  '[아트박스 POOM/바이빔] [LED] 케어 벽걸이 스탠드-그레이',
#  '[아트박스 POOM/바이빔] 쁘띠6등 샹들리에-화이트',
#  '[알찬쇼핑]-목문레버_3300도미안그레이_좌 손잡이용품 문레버 도어용품 손잡이 레버',
#  '[앙상블커튼] HS-듀오 매직 콤비 롤블라인드 95X240cm',
#  '[에넥스 ENNEE]로젠 슬라이딩 붙박이장-330cm',
#  '[에뜨와]비타민욕조[핑크] (77F0 86001)',
#  '[에스뜨레야] 에이블 피치스킨 이불베개세트(싱글)',
#  '[엔비하우스]진주보석 탁상시계 W/탁상시계/알람시계/인테리어소품/엔틱시계',
#  '[엔스기빙]친환경 한지 대사각 편백나무베개',
#  '[엠케이데코]36color 40수 순면 [이불커버 더블D+구름이불솜D]',
#  '[예반몰]나전 8치 흑송학 굴림 2단좌보석함(장태복 문화재기능인 작품)/나전칠기/전통공예/자개장식',
#  '[오디스샵] 중형 고급 돗자리 대나무소재 마작돗자리',
#  '[오플로어] 라반 라운드 600-1200 렌지대',
#  '[올리비아데코] 톰슨 광목 패치 누비요커버 S +기능성목화요솜',
#  '[우드스티커] 심플패턴 (반제품) - 입체우드 월데코 포인트 집꾸미기 벽장식',
#  '[우드스티커] 크리스마스 스몰트리 (반제품)',
#  '[우리꼴][우리꼴자연가구] 우리꼴 원목 약장CD장 (3X4단)',
#  '[웨스트프롬] 모던뮤뮤C) 900 소파테이블 / 크림',
#  '[윈지스토어]브론즈하우스 MHC-010 명화 자작나무 벽시계 벽장식 인테리어 결혼 집들이 개업 선물 축하 모',
#  '[이케아]IKEA  SUDDIG 이불커버+베개커버, 블랙 202.732.16',
#  '[좋은가게]퀼트실 58/일본 후직스/폴리에스터 100？50m/핸드퀼트or머쉰퀼트 모두사용/미싱에 사용/쏘잉스',
#  '[좋은느낌]일체형어린이집낮잠이불_쥬쥬랜드',
#  '[총알배송]-()미니다리미판 4843 다리미 다림미용품 다림팜 다리미판 좌식형다리미판',
#  '[총알배송]-힘센매탈랙선반19Ø 4단600 선반대 베란다선반 철제선반 메탈선반 철재선반',
#  '[키즈돔] 코끼리 차렵이불 매트커버세트(싱글/슈퍼싱글) / 아동주니어침구',
#  '[키즈돔침대]안나 2인용 원목 캐노피 침대(화이트워시)',
#  '[태윤퍼니처][까미엘]HNK 편백나무 원목 평상형 쇼파(SZ_EC0060)',
#  '[태윤퍼니처][까미엘]샤이니 3R 장롱 6종 택1(JM_AH0135)',
#  '[특가쇼핑]-스테인드글라스 거울 jy09벽거울 스테인드',
#  '[퍼니플라자]책상시리즈/H형책상/책상/일자책상',
#  '[퍼시스 소파] 3인용 천연가죽 소파 CS3103 (중역용)',
#  '[퍼시스몰] [CS4103] 퍼시스 소파/세티나 3인용소파',
#  '[퍼퓨먼스] 오드 아로마 리드디퓨저 시트러스 버베나 200ml 실내방향제/천연방향제/아로마디퓨저',
#  '[펫월드] 울트라 퍼피 토일렛(대형) / 애견용 화장실',
#  '[포시즌홈]더하우스룸 광목로즈힐 방석(60-60)',
#  '[필루미네이트] UNISEX Basic Logo Heavy Hoodie-Dark Blue',
#  '[필립스조명_PHILIPS 램프_ESSENTIAL 20W 6500k 형광등색(주광색)-2개 세트]',
#  '[하우스인] 라온 수납서랍형 아일랜드 홈바 (착불)',
#  '[하우쎈스] 파퓰러 차렵 누빔요 풀세트 (2인용)',
#  '[하이솔로몬] 모티브 보조스툴 (1인용)',
#  '[한마루] 로미오 좌식 화장대/ 한마루',
#  '[핫트랙스] C-핑크계열 - tj001-가슴이뛴다_현관문방문시트지',
#  '[핫트랙스] [콩지] 왕 별쿠션 60 (솜포함)',
#  '[핫트랙스] 눈내리는 밤 워터볼',
#  '[핫트랙스] 레드 - 필웰모던스퀘어디자인의자',
#  '[핫트랙스] 블링블루메쉬 - 듀오백 듀얼린더 ai ai-050M',
#  '[핫트랙스] 여름숲 어린이집 낮잠이불 - S(85*105)-유아용',
#  '[핫트랙스] 체리 - [포장지훼손 특가] 스위트 미러 손거울',
#  '[핫트랙스] 쿠션솜 추가 - nother Dog Natural Cushion / 나더 강아지 프린트 쿠',
#  '[향기담은][에슐리 버우드] 영국 명품 에슐리 버우드 디퓨저/방향제/리필/디퓨저병/아로마/꽃리드증정',
#  '[헬렌스타인] 프리미엄골드 토퍼 패드형 싱글+방수 매트리스 커버 싱글+면프로텍터 싱글',
#  '[홈플러스]나라홈데코 헬로키티리본입체베개',
#  '[후추통][꾸밈]ij003-달나라 소녀와 별나라 소년/그래픽스티커/아이방꾸미기/캐릭터/달/별/소녀/소년/인',
#  '[후추통][꿈비][미미루] 빈백소파 드몽 - 유아용소파/빈백/소파/완구/미미루/드몽/가구/유아동가구/소파/',
#  '[후추통][디자인베이]포인트스티커 레터링스티커_08 (반제품C)시트지 벽지/영문타이포/글자/시트지포인트',
#  '[후추통][뭉키데코]현관문시트_비행기를 타고 하늘을 날아요 Ver_02/뭉키데코/인테리어스티커/그래픽스티',
#  '[후추통][수풀][컬러 안개시트]러블리 래터링 LCW 11/커피숍/카페/글라스스티커/유리스티커/사생활보호/',
#  '[후추통][아스파시아]사랑합니다 카네이션 디퓨저 세트/어버이날/스승의날/카네이션/디퓨저/방향제/플라',
#  '[휴잠]쁘띠 경추 반달 메밀베개',
#  'e가구 루미 5단 800 서랍장',
#  'fp376-무늬목지사패턴고급시트지_인테리어필름',
#  't-5슬림형 형광등 데코램프 형광등기구세트 간접조명',
#  '가구대장 원목 52-47 옷장+h형책상 벙커침대 S',
#  '가구엠디 레마하우스 와이드계단선반800',
#  '가랜드 YG 04 홈인테리어 월데코 모빌 가랜드',
#  '가정용 업소용 망사 선풍기 안전망 선풍기 여름 안전',
#  '간이 원형 탁자 야외 사각 식탁 야외용 원목 테이블',
#  '강화유리레터링파티션 인테리어디자인칸막이H1800 60T',
#  '건강한 소재로 만든 편백나무벽지,제일천연벽지 나무/3001-8',
#  '건전지로 돌아가는 대관람차 오르골 관람차회전오르골',
#  '겟홈 루비 원목 600 h형책상+600책장',
#  '경첩/정첩/문/방문/도어/가구/DIY/4x3.5/NI',
#  '고급 천연갈대발45cm/업소용 문발/식당발/창문발',
#  '골드 실버 쿠션 커버 쇼파 등 거실 트리 녹색 사각 멋',
#  '공주거을탁상거울콘솔거울거울 인테리어 소품 김포소품 서울소품 생활소품거울 탁상거울 콘솔거울 소품 김',
#  '교육비 신청함/프로방스MR/프로방스 메모꽂이 레드 우체통/건의함/칭찬함/소리함/의견/다파라',
#  '국내제조 고급 구름 쿠션솜60×60',
#  '국산 LG 파크론 주방매트/냉기차단/충격흡수/주방발매트/씽크대매트/욕실매트/발매트/거실매트/다용도매트',
#  '국산 조립식 스텐레스 8단 신발정리대',
#  '그레이 스트라이프 면 이불커버(SS)',
#  '극세사 퀼팅 4단 쇼파패드/ 르헤브',
#  '기획찬스/ 다송/지압형라텍스 대형베개/듀폰속커버+극',
#  '깨비(옐로우) 고품격 주니어 침구세트+누비패드 S/SS 60수 사틴면',
#  '꾸미기닷컴 cy254-카페쉼터/인테리어액자세트/디자인액자세트',
#  '나르샤 핑크 어린이집 앞치마/선생님/교사 앞치마',
#  '나무상자닷컴 cm336-식물일러스트_유리문시트지',
#  '노블리스 3단접이식 빨아쓰는 매트리스 멀티싱글 7cm(커버+케미칼텍스 매트)',
#  '눈사람 22Cm (옐로우) -//크리스마스장식/테이블데코/파티장식/트리데코/장식인형',
#  '눈사람 인형 130cm/키높이조절 크리스마스장식인형',
#  '눈사람양말 크리스마스/트리장식 장식양말 트리양말',
#  '닛산 장기렌트카 370Z 장기렌트견적 리스가격비교',
#  '다목적 이지 워터쿨매트] 여름매트 쿨방석 캠핑',
#  '다발해바라기양면시계 브라운시계 예쁜양면시계 소품',
#  '달콤 리락쿠마 목쿠션/침구점판매용 팬시점판매용',
#  '대폭-Ice원단]래쉬가드-핫핑크(a1075)  원단 패브릭 천 부자재',
#  '더블/쿨매트/여름/2인용/매트/요매트/쿨젤매트/쿨메트/냉매트/아이스매트/쿨링매트/냉수매트/침대/시원한//',
#  '더크림 드레스룸 ㄱ자 2400x1600 파우더형 (3종/택1)',
#  '데코뷰 코지아 린넨커튼',
#  '독보적품질 프리미엄싱크대수전 싱크대수도꼭지 주방',
#  '동서가구 비이 소파베드-2인 DF6329H5',
#  '돼지고기 앞다리 찌개용- 500g 생돼지고기 돼지 한돈',
#  '등가슴받이 조절/체스툴 백어택 학생컴퓨터책상 편한의자/사무용가구 바른자세체형교정/높낮이회전조절가능',
#  '라바/라바이불/100% 국내생산/기능성이불/라바 스윗걸 마이크로 차렵이불(S)',
#  '라바티 허브차 리필팩 10종 선택//캐모마일/루이보스',
#  '라이프스토리[더 프리그]천연목화요솜  목화 요 솜',
#  '라이프스토리[마이홈스타일리스트]크리즈 베개커버 [그레이]',
#  '라이프스토리[베가]골드캐슬 우드 오르골',
#  '라이프스토리[스타일링홈]네오투톤 그레이 아일렛 암막커튼+속지커튼(중형)',
#  '라이프스토리[앤코튼]샹들리에 아치바란스',
#  '라이프스토리[플라워트리]펄스타가렌드 100cm-P 골드',
#  '라이프스토리[행복디자인]베이직 모던 앞치마 (2 COLOR)',
#  '라임 400옷장',
#  '라임라잇/모던라인-ReFresh 베개커버',
#  '랑콤미라클/프래그런스오일100ml/캔들/디퓨저',
#  '레이디가구 아이룸 600 3단 서랍장/베이비장',
#  '로지(레드)코디 2인용베개(솜포함) 50x110 40수 순면/ 블루밍데코',
#  '롤리팝 커플 핸드폰줄 2개세트/공예/교구/바느질/인형만들기/펠트diy',
#  '루벤스 600 고무나무원목 협탁 침대/미니협탁',
#  '루피망고실 내츄럴망고 울100% 털실 250g 국산 뜨개실',
#  '리락쿠마 다용도정리함 사무용품 리락쿠마정리함 책상',
#  '리스펠 전신경/전신거울/ 베이직팩토리',
#  '마에칸(마이깡)단추 18p 바지걸고리 바지후크 다용도',
#  '멀바우 15T/재단목재/절단목재/DIY원목재단',
#  '메모리폼 베개',
#  '메모리폼 솔리드 러그(170x230cm)',
#  '메모리폼 허리쿠션 등받이쿠션 다용도쿠션 쿠션 허리받침용쿠션 메모리폼',
#  '면리본 - 집 MC 1.2cm X 1m가격 국산 고급리본',
#  '면마 쿠션방석/보험판촉선물용 쇼파의자 방석',
#  '모나코 대쿠션/대방석 솜포함 ( 중형형사이즈 ) (KT면 100%)/ 위드인하우스',
#  '모니터받침대 거치대 USB 허브 MC-300 HUB',
#  '모던 엔텍 스퀘어 램프(1P) 아로마램프 인테리어소품',
#  '모던탑21 이지-슬림 1400 홈바형 아일랜드식탁 [단품]',
#  '모두몰,4680TS  한독 괘종시계.벽시계.추시계,인테리어',
#  '모디쉬 베네치안 벽거울',
#  '목봉 지름40x300~1200/50x300~900 칼라봉20x600~1200',
#  '무늬목시트지 1롤 50m 시공구4종포함 DC-DBIT-422D 12',
#  '무료/특가-색동 앞치마 다용도앞치마 주방용품 주방용앞치마 주방소품 주방소모품',
#  '무배(267940)천정조명LED면조명 50W 키즈 로켓',
#  '무배-특별가]-APR소녀의 꿈 원피스형 앞치마_5pcs 주방앞치마 선생님앞치마 앞치마 주방용앞치마 다용도앞',
#  '무선차임벨 세트1개 경보기 차임벨 초인종 무선도어벨',
#  '무소음 우드 추벽시계 CHT-304/ 하이아트',
#  '무장식리스 75cm TRNOES',
#  '미니 캔들 라이터',
#  '미니멈룩_프리미엄 이카루스 35mm 샤기카페트 - 100x1',
#  '바렛 그레이네이비 3인용 패브릭소파(쿠션 1개포함)/ 우아미가구',
#  '바로크홈 퍼페딕 접이식 매트리스/ 베이직 12cm 싱글',
#  '바보디자인[꾸밈]is342-맥주한잔하고싶다_포인트스티커[무료배송]',
#  '바보디자인[더 프리그]엘레나 - 국내제작 핸드메이드 면 쇼파패드 - 2color',
#  '바보디자인[르우홈]메이주방장갑',
#  '바보디자인[수인아트]버샬 화병도자기화병',
#  '바보디자인[자유공간]우드블라인드50mm참피나무_5010',
#  '바보디자인[해피툴]k 린넨체크 바란스',
#  '바보사랑 마이홈스타일리스트 퓨어캐쥬얼 베이지 커튼',
#  '바보사랑[빈그릇]빈세라믹 캔들홀더',
#  '바보사랑[안나하우스]세븐 말가렌다',
#  '바보사랑[진바스]행복한 롱다리 양털 눈사람 인형 - 레드',
#  '바보사랑[케미에르][케미에르]앙제르 침대협탁 KRM-935[무료배송]',
#  '바보사랑[퍼플박스]2링 화이트 드림캐쳐',
#  '바보사랑[해피코튼]해피코튼 캐릭터 짱구베개_젠틀베어 브라운',
#  '바보친구[더 프리그]원형 쿠션 솜',
#  '바보친구[바이빔]하운드 러그(100x150)-반평[무료배송]',
#  '바이빔 헬로우퍼피 면 러그 100x150',
#  '바이소호/친환경 LG하우시스 무늬목 워시 MBEW390',
#  '반고존/2×3.5 탁상용 듀얼 아크릴액자/추천사은품 그림액자 아크릴액자 인테리어액자 사진액자',
#  '반지함 미용 세트 주거잡화 반짇고리함 반짇고리 바느',
#  '반짇고리(대)반짇고리/실바늘세트/반지함/바느질도구',
#  '버거의자/BG800/좌식/컴퓨터/가슴받이/학생/자세교정',
#  '베이직한 디자인의 무지실크벽지 서울 플레인/330-1 [화이트]/1롤 [5평]',
#  '베이직한 디자인의 무지실크벽지 서울 플레인/337-3 [아이보리/베이지]/1롤 [5평]',
#  '베일리 붙박이장-330cm/ 에넥스',
#  '벽걸이 우체통 MB-64283 독일제',
#  '벽걸이전신거울 대형전신거울 인테리어소품 화장대거울 콘솔 예쁜 전신거울 엔틱거울 와이드거울 제작',
#  '보라장미 티슈커버 휴지케이스 소품 화장지커버 휴지',
#  '보루네오하우스 엘리브 카티아 3단 서랍화장대 yg003',
#  '보조스툴 사각/인테리어/디자인/보조의자/화장대',
#  '복고풍 체크브라운 식탁덮개 테이블보2 130x180',
#  '봉제식와팬]청지닻 (99549)',
#  '봉황자개명함함 명함보관함 자개 명함케이스',
#  '분홍둥근영아책상(높이290) 유·아동 책상',
#  '비단금침/목단 누비한실 예단이불/무료포장',
#  '비비드컬러패브릭인테리어1인소파 /디자인소파 안락소파',
#  '빅스트라이프로만쉐이드레드155  주문제작/ 리빙데코',
#  '사각 방석(50X50 커버) 방석 의자방석 다용도방석 페브릭방석 인테리어방석 소품방석 장식방석 쇼파방석 사',
#  '사과(9cm)  FMYL141340',
#  '사랑나무 방석커버/쿠션커버/레드,그린/ 위드인하우스',
#  '사랑의천사종 추시계 (실버)',
#  '사무용의자 와이 원/컴퓨터의자/사무실의자',
#  '산타모자 별램프 크리스마스 산타복 파티의상',
#  '샤이니 나비 야광봉세트/행사 파티 콘서트 응원용품',
#  '샵오브코리아 하회(河回) 탈액자-양반,부네(가로)',
#  '선물가게/격자무늬 알파벳 무릎담요(110cm, 210g)/무',
#  '선시아LED 시스템방등 60W HR-60 LED시스템방등 (HR-60)',
#  '세인트샵 가죽 평상형 침대(킹) / 클럽/ 바로크홈',
#  '소형 악어쿠션 미니(35cm) 바디쿠션 롱쿠션 베개쿠션',
#  '솔리드 호박쿠션/솜포함/지름50/베이지,그린,네이비/ 위드인하우스',
#  '수지씨앤엘 벨벳 다이아 심플방석 1인용 와인 SZ0084',
#  '수퍼클래스 4cm 3D MESH 프리미엄 쿠션매트 SCWG-4015(퀸 퀸사이즈매트 편한침대매트 돌침대매트 퀸매트 메',
#  '쉐비 로즈 레이스 커튼 - 아이보리 [수입씽S]',
#  '스노우트리 포인트스티커 크리스마스 산타 시즌 겨울',
#  '스테들러 에고소프트 점보색연필(6색-158 SB6) 팬시색',
#  '스트라이프매트 (40x60m)  - 거실매트/발매트/다용도매트',
#  '스팀다리미(실버)',
#  '시그마 선시아 LED시스템방등 주방등 거실등 선시아방등 (HR-30,HR-60,LS960X,LS925(W),LS950(W))',
#  '시그마(쌍사) 20W 블랙램프 야광램프 나이트조명 (SIGMAB20)',
#  '시니프 에센레자의자B2WL0009',
#  '시분초시계 2p 타이거 T6200/인테리어시분초벽시계2p/무소음무브먼트사용/선명',
#  '시원한 동물친구 얼음베개 / 여름베개 / 시원한 베개',
#  '시트마켓 cs082-잠자는 양_칠판시트지_칠판스티커',
#  '시트마켓 iy299-강아지의 여가생활_칠판시트_칠판스티커',
#  '신개념 무지실크벽지 신한 심플 / 19002-15 플레인[바이올렛]/1롤[5평]',
#  '심쿵 이불 쿠션 8종 모음/담요 낮잠 어린이집 캐릭터',
#  '아이앤루디800컴퓨터책상세트TGW',
#  '애니프렌즈 U자 대형 바디필로우',
#  '액자용 장식볼트 은색 다보 모음 DIY철물 / 볼트 다보 장식볼트 철물 DIY',
#  '앨리스고즈홈 아로마 피톤치드(올리브) 암막겹가공 400, 봉, 링',
#  '앨리스고즈홈 칼토(브라운) 암막 320+속커튼300,봉,링,레일',
#  '야외용테이블 사각/카페테이블/야외테이블',
#  '양철 로봇 알람 시계 ver.1 (5color) 핑크/시계/탁상시계/알람시계/무소음시계/자명종/로봇/로봇시계',
#  '양평군 레드 눈꽃 크리스마스 산타모자(4',
#  '엔틱 타이백 (2개한세트)',
#  '엘레나161 클래식장스탠드 탁상스탠드 장스탠드 인테',
#  '엘르파리 컨버스 패드 SS_블루 핑크',
#  '엠보[中]단스탠드/ 비스코',
#  '오란  JF 꿈나무 전면 책꽂이 책장',
#  '오르다 단면 구스 토퍼 (고급형)',
#  '오스람/OSRAM/LED 볼전구/9W/9.5W/글로브/램프 조명',
#  '오아시스 롱다리눈사람인형(120cm) 어린이집 성탄절',
#  '오클로버 일반용방석 핑크 방석 휴대용접이식방석 휴',
#  '옥색열린학습대(기본다리)-초1~3학년용현대교구,유치_',
#  '온오프 포플러 우드T149/잉글리쉬 월넛',
#  '올리비아데코 릴리 순면 요차렵세트 S +견면요솜',
#  '올리비아데코 릴리 순면 요차렵세트(Q)+NEW목화요솜',
#  '욕실인테리어 팬더_휴지걸이/휴지케이스',
#  '원목영아사물함(6인용) 사물함',
#  '원형 매트 러그 카페트 극세사 쿠션 거실 장식 인테리',
#  '유니온 차량용 표지판 포맥스 택1 안내판 알림판 케이',
#  '유로판손잡이 색상선택 가구손잡이(2579)피스4 서랍장',
#  '유정사튤립지펠냉장고손잡이-색상랜덤발송',
#  '이불장 연두/유치원교구 유치원이불장 학원이불장 유아이불장 아기이불장 소품장 옷장 옷정리장 유치원가구',
#  '이쁜방석 쿠션방석 의자쿠션 스펀지쿠션 스폰지방석',
#  '이지-웰 일반형   렌지대 전자렌지대 렌지다이 전자렌지수납장 주방수납장',
#  '이케아 EKBY JARPEN /VALTER 벽선반, 79x19 cm IKEA',
#  '이케아 엘마렌 후크2개형 수건걸이/수건행거/수건후크',
#  '이케이 삼나무 원목 화장품정리대 거울부착 1단정리대',
#  '인도식 인센스 / 고네쉬 인센스 스틱 - 무스크(머스크)',
#  '인조가죽원목회전 인테리어의자/카페의자 커피숍의자 식당의자 디자인의자',
#  '인테리어 두루마리 휴지 케이스 생활용품 티슈케이스 집들이선물 휴지케이스 장식소품',
#  '인테리어 스위치커버 그래픽스티커 파인애플 WBSS7170',
#  '인테리어시계/블루밍체리 양면시계[실버] 1304-2',
#  '인테리어필름 포인트시트지 리버스체크 블랙펄 WBIM96',
#  '인트리 니콜 이층침대 No매트리스 분리형',
#  '일반타입센서등_SI5021_백열등60W이하_1EA 현관조명',
#  '입큰 에센스3 큐브 파우더 21호 30g SPF27PA 파우더',
#  '잉글리쉬페어앤프리지아/프래그런스오일100ml/캔들diy',
#  '전사쿠션담요 판촉물기념품사진컬러인쇄제작홍보광고',
#  '전신거울/미용실/디자인/거실/화장대/드레스룸/맞춤제작/쇼핑몰/스튜디오/의류매장/개업식/ 674 다크브라운',
#  '접이식 LED 수면등/산후조리원용 수유등 랜턴 램프등',
#  '접이식 접철 탁자(흰색)',
#  '접이식원목의자(701외)/야외용/까페의자/데크의자/접의자/식탁의자',
#  '제이제이몰 3분 모래시계 미니 양치 요리 타이머 시간',
#  '조쉬 퀸/킹 홑이불베개커버/선염면/블루,오렌지/ 위드인하우스',
#  '조이시스 코야 패브릭 3인용 소파베드 (풀거버포함)',
#  '주방싱크수전 절수헤드 주방부속 절수헤드 주방헤드',
#  '줄리앙 단스탠드',
#  '중역용의자/pc방의자/게임의자/학생의자/사무용의자',
#  '지오바니 퀸/킹 누비매트커버세트/40수트윌면/ChitoFix항균가공/페일블루,카키그레이',
#  '지지독의 세련된 인조가죽 모던&버튼다운 좌식소파/쇼파베드/대쿠션 방석셋트/최대190cm-csp780',
#  '징 장갑바늘 니트프로 부자재/독일/매탈 바늘/부자재',
#  '찰리시리즈 고무나무원목 이층침대005 싱글/ 더리드우드',
#  '책꽂이 4단-하늘 팩 2개입',
#  '책상1000-그린.레드 책상 일자형책상 학생책상 다용도책상 일반책상',
#  '천싸요/1개)한복장식-삼색동',
#  '체어캡소 시리즈 유아용품 의자커버 안전용품 체어캡',
#  '초록문패 현판 고급형 입체현판 No.20 (中)',
#  '침대 매트리스 방수 속커버 슈퍼싱글 22 사이즈 밴드',
#  '카르멘 퀸/킹 누비이불베개세트/멜란선염면/브라운,민트,퍼플,그레이',
#  '카카우드 탄탄 낮은 벙커침대(원목마루)',
#  '카파-스마트정리함(12단-주황-K14041-02) 다용도수납',
#  '카파맥스 3단 책꽂이 (2색상) (1팩 2P) 책정리 책꽂이',
#  '캐릭터북앤드(나무) 사무용책꽂이 문구용책꽂이 책꽂',
#  '커넥터펜 10색 and 보타니컬아트 컬러링북 플라워편',
#  '코로나 화이트 장스탠드',
#  '코텍스 아오리/k-311/창문잠금장치/안전바/걸쇠/보안/부속철물',
#  '쿠션솜/구름솜/포솜/ 1kg/부자재마트',
#  '크라크라 유아소파 여우뛴다!/ 아이쿠우',
#  '크리스마스 PE.PVC혼합장식리스 800-골드[램프증정]',
#  '크리스마스 산타 망토세트-소/산타복/이벤트/파티의상',
#  '크리스마스 산타양말 트리장식/크리스마스소품',
#  '크리스마스 수입단추4976   원단 패브릭 천 부자재',
#  '크리스마스 화이트 양말(25cm×40cm) 성탄양말',
#  '클라인 가죽 3인+카우치 소파세트 (2컬러) / GE1374-1',
#  '타이포그라피 포스터 Think positive (T123)',
#  '타일벽지/비닐벽지/방수벽지64021-1/롤단위 길이15.5M',
#  '탈춤 문종 현관종 현관문종 벽장식소품 도어벨 인테리어장식',
#  '태양광야외조명 태양광잔듸등',
#  '택배 무료+에폭부엉이2P-레드 문종/문종/풍경/도어벨/리스/현관종/현관문종',
#  '토니(블루) 대방석세트(솜포함) 40수 순면',
#  '티메이드 MX814 디자인 거울 벽거울 화장대 거울',
#  '파워 스틸다리 듀얼 학생용 요추 의자',
#  '패브릭버튼3인스칸디나비아소파 /북유럽인테리어',
#  '페인팅느낌이 풍부한 디아디[DID]실크벽지 컬러스[COLORS] /5531-3 /1롤 [5평]',
#  '편백루바(히노끼루바)무도장 유절 10.TX100X500mm',
#  '포커스 LED 투광기 40w 야외투광기 야외투광등 조명',
#  '포티스 47pcs 수공구세트 808536 공구세트 쉐필드 오',
#  '폴라1등 펜던트 [5color]식탁등/주방등/인테리어/조명',
#  '프라젠트라 마더스 스킨케어 크림 100g',
#  '프럼스마일 실속형 멀티컬러 미니스탠드1P(색상랜덤)',
#  '프럼스마일 피노누아 라인딩 와인디켄터 1P',
#  '프럼홀릭 디퓨저 리필오일 250ml 9가지 향',
#  '프레도 전동 1인 천연가죽(소가죽) 리클라이너 소파',
#  '프렌치오크 오크우드 무늬목시트지 방문시트지 광택시',
#  '프리미엄 딥 요솜&토퍼 (Microfiber&duck50%) SS Szie/ 한국침구예진',
#  '프리미엄 초광 대자리 점보 180X230cm/대나무/돗자리/대나무돗자리/여름자리',
#  '프리킥 싱글/슈퍼싱글 누비이불커버/특면트윌면/BioO2항균방취가공/네이비',
#  '플렉사 베이직 trendy_벙커침대_space (화이트)',
#  '필립스 6995Z 1000W G22 230V 무대조명용 특수조명 할로겐램프',
#  '필립스 스탠드 44501(핑크) [마이버디/ 테이블스탠드/ 어린이친화적디자인/ 밝은LED램프/ 독서등 ]',
#  '필웰쿠엔코수납장세트(서랍둘)+식탁',
#  '하이플러스가구 협탁 2단',
#  '학교폭력신고함/하트철망G 그린/그린우체통/하우스우체통',
#  '한샘 프리미엄 윈도우 99㎡_30type',
#  '한지마감재(가루풀.100ml)/한지공예/한지체험학습문구코리아',
#  '한지마감재(가루풀.100ml)/한지공예/한지체험학습문구코리아',
#  '해나(Hanna) 1800 테이블 PF135/ 나무뜰',
#  '핸드타올 스카트R 스카트폴드 핸드타올 175매 손타올',
#  '헬로우키티 캐릭터 스탠드알람시계',
#  '헬로키티 애플 철재 티슈케이스(1482)',
#  '헬로키티도트패턴요추쿠션 등받이 허리쿠션 등쿠션',
#  '홈쇼핑매진상품 메르꼴레디 극세사 입체토퍼 Q 1 + 1',
#  '홈쇼핑정품 난방비절약/커버분리/온수매트커버싱글',
#  '황사/미세먼지/자외선/차단/KF80/3중필터/의약/마스크',
#  '흡착형 코너용 수건걸이 SQ-1027',
#  '힐링 의자 대 의자 플라스틱의자 보조의자 회의용의자',
#  '(((FR-K13PXES/동부대우 뚜껑형 김치냉장고117L/호텔사업자/호텔가/ 설치장소별 차등적용/H)))',
#  '(((SEH-350GY/미니히터/카본/0.7KW )))',
#  '(16년형/기본설치비무료) 2in1 멀티에어컨 PVS-166PWH',
#  '(BZ)보인 BLS-01L 탁상용 브라켓/23~55인치/대형티비',
#  '(GM)한일웰빙온돌마루 카페트매트특대형 270cm',
#  '(HD한일전기 업소용 청소기_HC-1900W 업소가전 산업가전 업소청소 산업용청소기 업소용청소기',
#  '(IT) 캐논/CLP-306/3000안시/당일발송/친절상담',
#  '(JJH 신일 무선 핸디 청소기 SVC-680G 미니청소기 무',
#  '(JJH 신일 무선 핸디 청소기 SVC-680G 신일청소기 미',
#  '(JJH 홍진 탁상용 선풍기_HJ-16 가정용선풍기 개인용',
#  '(JJH신일 다기능 믹서기_SFM-2000DLI 분쇄기 일반믹서',
#  '(JJH신일 인덕션 전기레인지 SHL-HM20 인덕션전기렌지',
#  '(KANALS) BK7001N BK-7001N ENTERGRAN 무선마이크 900MHz 핸드 핀 벨트팩 1채널 / 인기상품 특가 할인 진행 중! 음향기기 전문 엠사운드몰',
#  '(MNM에어커튼 2모터 DSA-1200S (날벌레차단.외부공기',
#  '(PLM조아스 전기면도기 SR-297 6날면도기 조아스면도',
#  '(PLM해마루 벽걸이겸용선풍기 hm-400f 여름가전 여름용품 벽걸이형선풍기 계절가전 탁상용선풍기',
#  '(WS빠른배송)삼성 업소용청소기 VC-R935D 건식',
#  '(is) 브리츠 BR-1800T3/2채널스피커 앰프일체형/무선리모컨/원목 PC스피커/RMS출력 70W/매장/거실/TV스피커/PC스피커/BR-1800T3//스피커/컴퓨터스피커/브리츠',
#  '(미싱샵)이스트만 (EASTMAN) 고속 7인치 재단기 명품 재단기 공업용재단기 핸미재단기 오픈초특가상품',
#  '(오렌지미싱) 본봉 조기노루발 가이드노루발 공업용',
#  '(이지넷) NEXTLINK-DPHC220 2M /케이블류',
#  '(진공비+벽걸이설치+기본설치비포함)삼성(스마트에어컨Q9000)홈멀티형AF16J7371WFR(52.8㎡+18.7㎡)랜드',
#  '(추천) [엘나미싱 explore220] 엘나미싱 재봉기 재봉틀 미싱 미니재봉틀 가정용미싱 가정용재봉틀 손재봉틀 홈미싱 공업용재봉틀 가정용미싱 가정용재봉틀 손재봉틀 홈미싱',
#  '(카본 원통형 히터 HV-2028F) 전기히터/원통히터/전기난로/카본히터/2600W히터',
#  '(터치미 칫솔살균기 TM-2500)칫솔살균기 욕실용품 치',
#  '+(hit)+[-신일산업-] 신일 SVC-H23WYM 청소기 [저소음 강력모터 탑재/저중심설계/핸디형 무선청소기/핸디형청소기/진공청소기/미니청소기/소형청소기/스틱형청소기]  신일청',
#  '-156 극저온 아즈텍 금장 미니형 말굽 단자 [ 2개 1조 ] //  Mini Banana plug / 바나나단자 / 스피커단자',
#  '-3-지우컴퍼니 [OPTOMA] DLP프로젝터 EX538 3000안시/XGA/3000:1/2.3kg',
#  '/빅패널 쿠킹타이머/요리/디지털/스톱워치',
#  '10m 15m 전원케이블 3구전원 3구전원케이블 3구클로버 3구크로버 컴퓨터 모니터 TV 노트북 프로젝터 LG 미니빔 빔프로젝터 빔프로젝트 클로버 크로버 전원 케이블 3구 클로버전',
#  '11번가초특가세일/린나이정품/LPG/LNG/RT-1010/스마트센스/크림화이트',
#  '12인치 책상용히터/선풍기히터/미니난로/사무실난로',
#  '16형 22형 31형 웰템 아이센 이동식 에어컨 업소용 산업용 실외기 설치가 필요없는 에어컨',
#  '1시리즈 장기렌트 BMW 리스 비교견적 렌트카장단점',
#  '2 [KRT] LG전자 클래식 오디오 CM3530 (라디오/USB/CD/오디오/스피커/미니오디오/모던/아날로그 감성/블루투스)',
#  '2016년형 NEW 에어워셔 MAPH-R576W 단독공기청정/가습',
#  '2016년형(카스 정품)스텐드형 원적외선 칫솔살균기(HTS-2900)/칫솔살균기/칫솔/',
#  '2017년 신제품 스타리온 석유 난로 SH-R155SCH/히터',
#  '2017년형 대성하이원 DSPE-200 전기난로 전기히터',
#  '2017년형 핫템 USB 고리형 무릎담요 물세탁가능',
#  '2구 전기렌지 빌트인 쿡탑 매립 전기레인지 매립형 독일 하이라이트 프랑스 세라믹 글래스 강화유리 ERA-B20FM',
#  '32S 브라운 면도기망/날 교체용 뉴시리즈3호환/ens',
#  '360도 좌우회전 레펠멀티 리모컨선풍기/신일선풍기/선풍기/스탠드선풍기/벽걸이선풍기/삼성선풍기/타워형선풍기/업소용선풍기/이색선풍기/한일선풍기/타워팬',
#  '45 -70 일반형 LCD 거치대 티비 벽걸이 브라켓 TV거치',
#  '8000USB선풍기/휴대용선풍기,냉방용품,usb선풍기,탁상선풍기,플라스틱선풍기',
#  '8단 대용량 투명트레이 높이조절 식품건조기 높이조절',
#  '::신형우퍼 패키지::[YAMAHA] 야마하 NS-F700 5.1ch(NS-SW300)::5.1채널 스피커세트::스피커스탠드, 스피커케이블, 방진볼, +PDX-B11+ 사은품 한정',
#  '@MD강력추천정품@웰빙요리/그릴/쿠커/전기그릴/미니오븐/로쏘울프/요리도구/홈베이킹/컨벡션/광파오븐콤보 고급형/',
#  'ATEN UC-100KMA USB to PS/2 Converter UC-100KMA 27475',
#  'AV3939 안테나 케이블(나사형). 10M 케이블 BNC케이블',
#  'AVR/자동전압조정기/20k/220v/정전압/노이즈컷/자동/',
#  'B&W 미니오디오 Z2 (iPod 도킹/AirPlay 스피커)',
#  'BAR형/2.1채널 바형스피커 우퍼스피커/강력한저음/TV/PC/MP3/게임기/연결스피커 터보베이스/선면한고음/BAR형/우퍼스피커/강력한출력',
#  'BS1000/BS-1000/교사용마이크(D8K3240)',
#  'BSW 스테인레스 계란찜기 BS-1336-EB',
#  'BSW 요구르트제조기/요거트메이커/청국장제조/이유식/웰빙간식/LCD표시창/유리용기7개/BS-15015-TMD',
#  'Britz 브리츠 BR-1600T3 2채널 스피커/듀얼RCA/무선리모콘/60W/고밀도MDF/사운드컨트롤패널',
#  'CMiK MK-B21 노래방기계 휴대용노래방 라디오 마이크 야외노래방 이동식뮤직박스',
#  'CSR-35WD',
#  'CU240M/CU-240M/인터엠/40W/컬럼스피커/내부스피커/실내스피커/옥내용스피커/스피커/벽부형스피커',
#  'DALI 달리 북셀프스피커 IKON2 MK2 하이파이스피커 리본트위터 깔끔하고부드러운사운드 -AV 전문상담-',
#  'DC 전원 케이블(5.5 MF) Y형/60cm 제작용(BB672)',
#  'DRETEC 드레텍 주방전자 저울 다목적 디지털전자저울 드레텍전자저울 주방저울 GT-502WT',
#  'DSLR 카메라선풍기 미니선풍기 휴대용선풍기 손선풍기',
#  'DWF-601L/위드위드/일반세탁기/소형세탁기/업소용세탁기',
#  'E5014-2 RF숫-MCX숫 변환 케이블30cm 연결 선 잭 단자',
#  'ECOV311.AZ [드롱기] [아이코나 빈티지]ens',
#  'EX1 외장형 SSD (512GB)',
#  'End Plug 엔드 플러그 ST-1200시리즈 모음전',
#  'End Plug 엔드 플러그 ST-1200시리즈 모음전',
#  'FC730B/에펠폰/강의용무선마이크/(A8E0415)',
#  'FR-A123LW/124L/소형냉장고/원룸/사무실/대우물류직배송',
#  'GC 필립스 SHB3060 (블랙) 블루투스 헤드폰',
#  'GC-114KDMP 1100L / 냉동실1,냉장실3 / 직냉식 / 절전운전 / 급속냉동 / 성에제거 [총판][도소매][최저가 할인판매]',
#  'GPX PC301B/CDP/CD플레이어/CD,CD-R,RW재생/60초충격방지/배터리잔량표시',
#  'HAKKO DESOLDERING STATION 474-84',
#  'HBA6331C 빌트인 가스쿡탑 3구 가스레인지 전국배송',
#  'HJ 필립스녹음기 DVT6010 8G 원거리녹음 보이스레코더',
#  'HR2100 필립미니스믹서기/분쇄기/순간작동 400W 1.5L',
#  'HR2195/07 필립스 믹서기/아방세 콜렉션 블렌더 ens',
#  'JBL STUDIO 590 5채널스피커 당일발송',
#  'JM-4 만능 천장용 브라켓 빔 프로젝터 프로젝트',
#  'JYOA 성영루디스 김치냉장고 BD/BC-446D 마이콤디지털/업소용김치냉장고/446리터/560리터/720리터/무료배송',
#  'K73PGY [LG] 진공청소기 [슈퍼싸이킹3주니어/트윈싸이클론/헤파필터 H14급/먼지통 1.2L/청소]ens',
#  'KOVEA 코베아 기가 썬 히터 KGH-1310 캠핑히터 캠핑난로 가스히터 가스난로 코베아히터 코베아난로 신형난로 로타리',
#  'KRS 0505 (C형) 중형살균기 자외선 소독기 칫솔 병원',
#  'KT Ann WHF-7000 배터리 삼성 LG 유무선전화기 충전지',
#  'LG DIOS 식기세척기 D0633LFN (6인용)',
#  'LG DIOS 전기오븐 MA324DBN',
#  'LG PF1000U 1000안시 프로젝트 스마트빔',
#  'LG공식인증(주)대명 FR2996NCZ 트롬 세탁기 세탁+건조',
#  'LG전자 6모션 FR24D7MQNZ 드럼세탁기 (아름가전)',
#  'LG전자 GS-465 온후크/플래시/유선전화기',
#  'LG전자 휘센 FQ181PT1W/ F-Q181PT1W/ 기본설치포함/ 진공비포함/ 기본타공 2회 포함/ LG전자 휘센 초절전 인버터 싱글형 스탠드 에어컨/ 냉방면적 52.8㎡/ 듀',
#  'LG전자공식인증점YKG/49UH6420/울트라HDTV/123cm',
#  'LG직영 코드제로-싸이킹 진공청소기 K94SGN 정품',
#  'LP-W0602VE [기본설치비포함]/LG휘센 인버터스탠드/15평형/무료 방문견적 및 상담/상승공조시스템',
#  'MARANTZ 무선네트웍 블루투스 APTX 리시버 M-CR511 [화이트]',
#  'NEW 신일산업 SIF-16CSH 천장형 선풍기 업소용',
#  'Numark TTUSB 턴테이블',
#  'Omega Arc Headphone Stand  헤드폰 스탠드 해드폰 거치대 헤드폰 보관 보관대',
#  'PB 정품 고급 헤드폰 스탠드 거치대',
#  'PF87K/LG 프로젝터/미니빔/LED프로젝터/HDMI/스마트빔/ABC코리아',
#  'PHILIPS HX6754/33 음파칫솔 2014년 신상품 소닉케어칫솔모4개+살균기+충전기+본체/ 헬시화이트  DNG',
#  'PL코스메틱 이레 헤어 린스1000ml',
#  'PM/그랜드우성 김치냉장고WSM-360K(1,2도어)-서울무료',
#  'PROJECT | 프로젝트오디오 | PS 01 WAVE | 턴테이블',
#  'Premium Sound Wood Headphone Stand 헤드폰 스탠드',
#  'QA1211/매장스피커',
#  'QS-2500 점보 퀸센스 대용량무선주전자 전기포트 2.5 L',
#  'RTR-20M01//가스레인지/린나이/2구/자동불꽃조절센서/고효율실드버너적용/택배배송제품',
#  'SF-WP2000 사파이어벽걸이온풍기 2KW  전기온풍기 PTC',
#  'SFEH-11000DKㅁ신일 원적외선히터/이동형/예약기능/전기식/25평형(82.5㎡)/산업현장/휴게소',
#  'SI/나노전자/NE-10000/전기돈풍기/난방면적: 99 ㎡ /튜브형 히터/발열량: 10,320 kcal/h',
#  'SK 2행정 오토바이 엔진오일 ZIC M5 2T 1L 예초기 엔',
#  'SONY 정품 MDR-E9 다이나믹 오픈형 이어폰',
#  'SOUNDART/ XP-840/ XP840/ 8채널/ 파워드믹서/ 사운드아트/ 600W/ 교회음향',
#  'SUH-155H 신일산업 초음파가습기',
#  'SUH-155H 신일초음파 가정용 가습기 미니3리터대용량',
#  'SZPA029/충전식앰프 이동식엠프 무선앰프스피커',
#  'TEAC 티악 스테레오앰프 A-R650 + 엘탁스 monitor lll 모니터3 최우수스피커선정 50주년기념 -AV전문상담',
#  'TH 특가 후레쉴드 어드밴스 진공포장기 FR-B100WB',
#  'TJ미디어 TKR-365HK 이동식 노래반주기풀세트 노래방',
#  'TT356170 테팔 익스프레스 토스터기ooo',
#  'USB 컵 미니 가습기 1개 USB가습기 컵가습기 미니가습',
#  'USB공기청정기 황사 컴퓨터 노트북 공부방 탈취 공기',
#  'USB선풍기 미니선풍기 철소재 탁상용선풍기 업소홍보',
#  'V-P1700JSW LG 업소용 청소기 VP1700JSW',
#  'VSSET21/VS-SET21/35평-40평/음향패키지/매장용앰프',
#  'VTR-8000/필립스녹음기+캠코더/녹음기/보이스레코더/영상촬영가능/50시간연속녹음가능/화면을보면서녹화가능/녹음기캠코더/녹음기카메라/필립스정품/녹음기/보이스레코더',
#  'XM-850PLUS 블루투스 스테레오헤드셋 FM라디오',
#  'ZOJE 9503-B01 조제 고속 1본침 수동 본봉 다이랙트 무소음 모터 내장형 미싱샵이벤트+전국 최하가 이벤트',
#  '[ 32GB ] 북큐브네트워크 북큐브 B-612 전용 전자책 외장메모리카드 메모리칩 이북 ebook MicroSDHC 마이크로',
#  '[5년무상!]위닉스 제습기 DHB-157IPWR 플라즈마 웨이브[1일제습량 15리터,플라즈마웨이브,1등급]-2',
#  '[AV홀릭]Q어쿠스틱 2050i 5채널스피커 월넛 + 아마하 RX-V475 홈시어터패키지 스피커케이블증정',
#  '[B9500] 캐논 미니 젠더',
#  '[Bezzera Ellisse]베제라/베쩨라/엘리제/엘리쎄 커피머신 2그룹',
#  '[Breville] 국내정식 브레빌 오렌지 착즙기 쥬서기 시트러스 프레스 800CP',
#  '[Britz] 브리츠 컴퓨터 스피커 BR-ORION /2채널 우퍼형 스피커/PC용/USB용/노트북 사용가능',
#  '[Britz]Britz BR-4900T2/2.1채널/독립형 오디오시스템',
#  '[Canston전문판매점] 캔스톤 LX-2200 Soundbar-D 사운드바디/2채널/사운드바 2016년정품 당일출고',
#  '[EPSON] ELPLP61 (EB-910W, EB-925, EB-435W, EB-430 프로젝터 순정품 램프) 무상 AS기간 : 6개월, 600시간 / 한국엡손총판대리점',
#  '[Esoteric] 에소테릭 A-03 스테레오 파워앰프回인터케이블 증정回A03回A-03 Stereo power AMP回esoteric amplifier回파워앰프回스테레오앰프回고급사',
#  '[FR-B153MW/145L]대우 일반냉장고/소형냉장고/미니냉장고/원룸/오피스텔/팬션/독신자/전국빠른배송/FL',
#  '[ID814]  Coms 블루투스 헤드셋 (White) - class2 지원V3.0+EDR, AUX',
#  '[JW800(16GB)] 30프레임 적외선녹화 간편조작',
#  '[KANALS] BK-802N 300W 무선마이크2대 휴대용/무선앰프/스피커/마이크',
#  '[LG전자]공식인증점(LG특급) LG광파오븐 MJ324SWT/LG물류직배송/폐가전무상수거',
#  '[OPTOMA] 옵토마 정품 DLP 프로젝터 HD86 Full-HD/1600안시/50000:1/사은품증정/당일발송',
#  '[PHILIPS 필립스 소닉케어 파워업 블루 HX3120/01]',
#  '[TOUCH ME] USB 충전식 손난로 터치미 1800mA -스마트폰 보조배터리  충전젠더 포함/손난로/충전식손난로/충전식/USB/',
#  '[Unclewilson] 고급 원목 오메가 헤드폰 스탠드 월넛  한정수량 - 특가판매   [이어폰샵]',
#  '[WINEAUDIO]어쿠스틱 솔리드턴테이블 Wood',
#  '[Y타입] 맥슨 MDC-9200 호환 무선전화기 배터리 (NI-MH / 1.2V / AAA / 2알)',
#  '[[강추위~걱정NO~!!]]한빛~튜브형~원적외선히터-6종/35~100사이즈-겨울계절가전/온풍기/보일러/전기히터/스토브/전기난로',
#  '[[홈레코딩 전문 마이크몰]] NT1A + scarlett 2i4',
#  '[iRIVER]아이리버 딕플[ D31/D33/D35 ]전용-[ 24핀 USB케이블 ]/딕플USB케이블/데이터전송 및 충전/노이즈필터장착/초고속배송',
#  '[mdc] CCTV 케이블 30m - 2RCA + DC 5.5 전원 회색 케이블 비디오케이블 CCTV케이블 CCTV 모니터케이블',
#  '[건식 8L 배낭형 1200W 강력 진공청소기 CV12D] 배낭',
#  '[금영 KHK-200 이동식노래방세트] KHK200/khk200/금영노래방반주기/금영가정용노래방기기/일체형노래방/이동형노래방/야외용노래방/노래방기계/금영정품/강당/팬션/노인회관/회',
#  '[네스카페]돌체구스토 미니미 그레이&화이트',
#  '[대성]DSO-91 /원적외선히터/돈풍기/백등유/튜브히터/9000Kca/1L/Hr/16평형/촉매필터장치/냄사,유해가스제거',
#  '[대웅] MD-230A 전자식 하이라이트 전기레인지 /조그다이얼/세라믹글라스상판/조리시영양보존/최첨단고효율 정품취급/총알배송(MD-230A)',
#  '[대원가전 허니문 THE BIG 잔치팬 DW-47000]전기후라이팬/전기팬/잔치팬/파티팬/피자팬/전기그릴/다용도',
#  '[대원가전] 허니문 DW-8700 피자팬(국내제조)잔치팬/마블코팅/전기팬/전기후라이팬/튀김기/전기그릴/전골팬',
#  '[뒷면] 아이리버 Ak240-2',
#  '[라디에이터] 한솔 HSR-2000GH/라지에이터/전기난로',
#  '[롯데 이라이프]휴대용가스렌지 고화력606/대한누리/생활용품/버너/캠핑용품/가스레인지/낚시용품/부탄가스',
#  '[리얼룩] 소니 워크맨 NWZ-A15 투명 액정보호필름',
#  '[리큅] 멀티쿠커 LC-81 슬로우쿠커',
#  '[리퍼상품] 아남 포터블 라디오 카세트 / 어학 A-30',
#  '[마란츠] M-CR611 + 야마하 NS-BP300 오디오패키지',
#  '[머리손질][그리에이트] 미니미니 멀티펌 롯드/12mm-30mm/퍼머롯드/ 빠른배송(기타)',
#  '[무료배송] / 아이리버 P100IPS/P10/P20/PMP120/PMP140/STORY(스토리) 전용 [미니5핀 국산충전기/케이블일체형충전기/가정용]',
#  '[무료배송] 남양아쿠아무선전기주전자 커피포트/미니/소형/휴대용/보온/포트기/여행/업소/라면/예쁜/캠핑/',
#  '[무료배송][스카이디지탈] 아리아판 FM(aria pan)턴테이블+ FM라디오를하나로 톤암기능/MP3저장/오토stop/7인치재생',
#  '[밀레(MIELE)][Miele]독일 명품 가전 밀레 식기세척기 G6100SC G6100 [신제품(고급)/뛰어난 세척력/에너...',
#  '[바텔] VT-D7000M(WH) 발신자유무선전화기/전체한글',
#  '[보성산업] 전기컨벡터 BC-125S /컨베이스/거실/동파방지/난방기/히터/욕실/화장실/DC',
#  '[빠른무배]-MNM저가형 1모터 에어커튼 ACL-1009 (리모컨) 에어커튼리모컨 실내온도유지 냄새차단 출입문에어커튼 저가형에어커튼',
#  '[사운드오션] MXL V88 MXL-V88 스튜디오 녹음 보컬 악기 퍼커션 콘덴서 홈레코딩 마이크',
#  '[삼성전자] [인증점] 모션 싱크 청소기 VC33F70LHBU [엠보싱필터 / 싸이클론]',
#  '[삼성전자] 인버터 멀티형에어컨 AF25HVWD1WKD /스마트에어컨/멀티형에어컨추천/스마트Q9000/딤플다이아몬드[기본설치비포함]DC',
#  '[샌드메이트 원형]도시락 샌드위치만들기 소풍 김밥 샌드위치메이커 샌드위치 샌드위치메이트 캐릭터틀 캐릭터샌드위치틀 샌드위치틀 샌드위치만들기 샌드위치메이트',
#  '[세아]ICIS-100 제빙기//1일제빙량90kg/얼음제조기/아이스메이커/제티스/공냉식제빙기/얼음제조기',
#  '[신일] 스탠드형 타워팬선풍기 SIF-TWS90 /풍량/풍향조절/강력모터/타이머/이동손잡이(SIF-TWS90) 정품취급/총알배송(SIF-TWS90)',
#  '[신일산업] 신일SPH-F15000/무연통펠렛난로/',
#  '[신일산업]메디펀o/ 핸디형 무선 진공 청소기 싹슬이 SVC-750SG/ 전기 핸드 청소기 차량용 자동차 용품 빗자루 업소용 로봇 반영구 필터 채용/ 강력 흡입(신일)반영구 필터',
#  '[악동몰]LED 무드램프겸 가습기 인테리어가습기 초음파가습기 에펠탑LED가습기',
#  '[야마하공식총판] TSX-B72 다크레드 블루투스 오디오',
#  '[예네 천장형 전기 온풍기 복합형 YH-017LVE] 욕실 화장실 사무실 식당 업소용 동파방지 난방기 난로 전기 히터',
#  '[예스뷰티] 매직 컬링 헤어 아이롱 전문가용 YB-377',
#  '[예은공조] 나우이엘  전기온풍기/NE-550NS/전기히터/02-711-3515',
#  '[오디스샵] 미니 요구르트 제조기 500ml 우유팩사용 요거트',
#  '[옵토마몰]옵토마 프로젝터 / z215st/ 3000ANSI/단초점',
#  '[윈지스토어]개별스위치형 멀티탭 3구 5호 5M 전기절약형 멀티탭 전기용품 멀티텝 멀티콘센트 멀티플러그 절전스위치 전체스위치 상품다양 상품다양',
#  '[윈텍무소음냉장고] 사일런스 화장품 & 다용도 냉장고(WC-20C) / 무료배송',
#  '[유닉스 헤어드라이기]확실한AS[정품]전문가용터보1800/음이온/UN2881/아이롱/헤어롤/예스뷰티/드라이기',
#  '[유파] 토스터기모음 TSK-2517/TSK-2569/TSK-P202 /와이드2구팝업/굽기조절/뚜껑/쿨터치/빵가루받침대 바쁜아침 커피/토스트(TSK-2517)',
#  '[이즈미] IKL-7504 전기 충전식 보풀제거기',
#  '[이파람]PW-F24CBS/냉방전용/79.2㎡실외기없는에어컨/수냉식에어컨/이파람에어컨',
#  '[인트레이드] 토클스위치 3P2단 250V 3A 녹색',
#  '[저소음 쾌적한 고효율 난방실현!]대성하이원 리모콘 원적외선 튜브형 난방 전기히터(8~13형)[DSPE-50]',
#  '[전자식 아답터] 파워텍 12V 6A 코드분리형',
#  '[정품] 엘보 보호대4521/뮬러보호대/뮬러 팔꿈치보호',
#  '[정품]업소용 오픈 냉동평대 쇼케이스 SALI-07FN (SALI-07FO) /A.S보장/무료배송',
#  '[중고][방송시연 스크래치상품] 키친플라워 맘스쿡 죽제조기',
#  '[중고]가우디 환경 음식물처리기-중고',
#  '[지방상담][당일발송] 스타리온 원적외선 히터 돈풍기/온풍기/석유온풍기/석유난로/난로 SH-F09SCG(82.5㎡) /석유히터/열풍기/전기난로/고속도로난로/고속도로히터/석유돈풍기',
#  '[차량용 회전식 면도기 JCA-8002] 면도기/차량용면도기/전기면도기/남성용면도기/조아스면도기/남친선물',
#  '[카타딘]사이폰',
#  '[카페클럽]코맥 커피메이커 모음 350 600ml/프렌치프레스/프레스기/티메이커/커피여과기/티포트/커피포트',
#  '[케니스]넥밴드형 블루투스 헤드셋 Muses2C 정품파우치증정',
#  '[쿠쿠정품/신제품]쿠쿠 식기건조기 CDD-9037T/CDD-9047 /마이콤방식/세라믹히터채용/8~9인용 AS보장',
#  '[키친몰]유니맥스 핫플레이트 1구 가스렌지/온도조절/위생성/안전성',
#  '[키친몰]전기물끓이기/박스형12리터/전기물통/전기온수기/정품/업소용/자동전기물끓이기/스테인레스',
#  '[토마톰스][아이리프]형태변화형 3X3 자연가습기 전용리필',
#  '[프라보스크] 거품기 14oz(약 420ml)',
#  '[하이마트] 파세코 슬라이딩 후드 PHD-S604 [풍향조절 2단/ 간단한 필터 관리]',
#  '[하이오디오]ION(이온) Pure LP 턴테이블 PC와연결 LP를 MP3로변환',
#  '[한경희 스팀다리미 HI-3020]대용량물통-2리터/3단',
#  '[한일] 800W 강력파워 만능다용도 핸드블랜더 HHM-800',
#  '[한일] 올스텐 환풍기 EKSS-40000  /환풍기/한일환풍기/욕실환풍기/소형환풍기',
#  '[헤드폰 이어폰악세사리 모음전]]이어폰연장선케이블 이어폰분배선젠더 이어폰솜파우치줄감개 이어폰고무캡',
#  '[헤라] 헤라 전기 헤어 클리퍼 - HR-280 [헤라] 헤라 전기 헤어 클리퍼 바리깡 [헤라] 헤라 전기 헤어 클리퍼 바리깡',
#  '[휴대용DVD]인비오PD2300(white)+NEW 페파피그DVD1집',
#  'ascaso Basic pod 아스카소 베이직 파드 - White',
#  'b((옵토마 W415 OPTOMA DLP 프로젝터 (WXGA 4500안시 15000:1 HDMI 렌즈쉬프트 상하)',
#  'e유림샵-케이블 전문) 다모일 DA-STC 1M-PINK 스테레오 케이블/3.5ST/핑크/스마트폰/스피커/오디오 -케이블',
#  '◆마이크로아쿠아쉐이버 초소형 방수면도기★홈쇼핑정품★휴대간편/출장여행필수품/여성다리제모/강력한파워',
#  '【Best™】윤씨네 80인치 수동벽걸이형 W-SV080KW 스크린',
#  '가스보일러 RC34-27 가스비절약형 보일러 시공 설치',
#  '가습기+공기청정기 MAPC-N226W 4계절사용 청정가습기',
#  '가정용 쿠션매직기 미용가전 고데기 고대기 헤어기기',
#  '건습식청소기 T-401 (1350W) 보흥클레온청소기 산업용,업소용청소기 베스트툴',
#  '고음질휴대용CDP  충격방지 흔들림방지 휴대용CD플레이어 CD CD-R/RW재생 /MP3 CD/ 군인용/POIH-LM2/학습용/어학용',
#  '곡성녹음기AT200 연속8일음성감지녹음기 증거잡는법',
#  '공장직송 용마기계 빙삭기 YMC-1001S(고급형)덩어리용',
#  '공장직영 본사정품  용마 두유기 YMC-300 수분이있는 콩가는기계/식당.가내식품 제조업체.업소용 AS보장',
#  '국산 LCD LED PDP TV 티비 천정용 천장용 브라켓 거치대 [LC-2200]',
#  '국산 한일 황토 참숯 온돌매트 더블 퀸사이즈 SM-1400',
#  '국산 휴대용 미니라디오 ES-505F 소형라디오 미니라디',
#  '국산 휴대용 소형라디오/TC-808F/TC-101PJ/TC-7007/TC-101PJ/TC-3003/ICF-S10MK/고출력 고감도 라디오 /',
#  '국산[J쇼핑아람]삼양/전기장판(중)- 전기난로/난방/따뜻한 겨울/사무실 업소 공장/좋은제품/빠른배송',
#  '굽기┃ 신제품 ┃오븐토스터기┃미니오븐기 ┃부스러기받침대┃ 강화유리 ┃타이머 ┃해동┃ 토스터기┃피자굽기┃치킨굽기┃떡 굽기┃고구마굽기┃딱딱함이 없어요~',
#  '그랜드 높은렌지 3구 1200',
#  '그린루프트 DGP-3100 /H13헤파필터/음이온 공기청정기 / 독일디자인',
#  '근적외선 벽걸이 히터 HV-505WR 무공해 청결 난방36.3',
#  '근적외선벽걸이히터 HV-1060 (1800W) 한빛난방용품',
#  '기업전화 / 업무용전화 / sk기업전화 / sk전화',
#  '김치냉장고 [신제품 출시] DOE123SXGH [전국본사무료배송설치][위니아공식대리점][무료폐가전회수] 신상품출시!!',
#  '나노카본 전기히터 NC-3000W 3Kw 팬부착/대성정밀/전기난로/3단 분리형/히터 난로',
#  '냉온수기물꼭지,정수기부품,암나사콕,수나사콕,항아리콕,정수기안전콕',
#  '넥서스 (NEXUS) AK-8000 정품 이온수기필터',
#  '녹원/허브 로즈마리 입욕제 100G 30개x 1박스/목욕탕/사우나/찜질방/쑥/녹차/한약재/업소용/한방',
#  '녹음기 IT-1000 8G mp3녹음기 장시간녹음 음성감지',
#  '녹주맥반석 JP-104 호환 KMV 카본 복합 필터',
#  '누비/누빔 본봉노루발/공업용미싱/종류선택/조은미싱',
#  '다이아몬드코팅 다기능 와이드 전기그릴팬 CHG-G2000W(국내최대용량/자동온도/전기팬)/ 쿠첸',
#  '대성하이원DGO-2117/원적외선돈풍기/난로/히터/온풍기',
#  '대웅모닝컴 DWO-SH2020 일반오븐/투명강화유리/파워코팅(왕세일)',
#  '대원정밀 DW-50000 5단온도조절/원형전기팬+찜기',
#  '대유위니아 10인용 딤채쿡 IH압력밥솥 DCH-A1001CGTW',
#  '대천 맛김 전장 재래김 30봉,파래김,돌김',
#  '델키 오뎅기계 DK401 업소용1구전기 어묵조리기/오뎅조리기/오뎅통',
#  '독일명품 퐁듀겸용 미니 전기튀김기+퐁듀포크/소형튀김기/홈베이킹/프라이어/기름튀김기/감자튀김/집들이선물/자취생/주방가전',
#  '동구 원두커피 머신 VEN-501',
#  '동부대우전자 FR-G514PDWE',
#  '동부대우전자 L32Q5310KK 스탠드형',
#  '동부대우전자 클라쎄 [FR-L803PRKM]',
#  '동양매직 WPU-6101F바이칼 전체세트 정수기필터정품',
#  '동양매직 슈퍼정수기+무료설치/냉수/정수/직수형',
#  '동양매직 업소용 기름정제기 CFM-043E/필터/정제기/튀김기',
#  '동양매직/라디에이터/CRH-R250E/13핀/동파방지',
#  '듀프렉스 커피메이커 DP-505C/12잔/가정용',
#  '듀플렉스 스팀 다리미615YS/ 듀플렉스다리미 다리미 생활가전 스팀다리미 세탁용품 홈패션부자재 가전제품',
#  '드레텍 디지털 타이머 T-291BL 99분59초 알람타이머',
#  '드롱기 에스프레소머신 EC680.BK',
#  '때가쏙비트 4kg(바스켓형) 비트 바케스 때가쏙비트 대',
#  '라라샵 버크 팬츠/와이드 통 삥줄 라인 쉬크 정장 바지',
#  '라셀르 탈착식냉동쇼케이스BD-258H(258리터)',
#  '레토 USB 로즈 미니가습기/장미가습기/소형가습기',
#  '롯데 휴대용라디오 PINKY-11 FMAM수신 고감도 이어폰포함 핑키11 미니라디오 음향 CDP 등산용라디오 카세트',
#  '리모컨 에어커튼 출입문에어커튼 냄새차단 에어커튼리모컨 냉풍기 공기문',
#  '리홈정품[무료배송]패킹/리홈 밥솥패킹/IH 압력밥솥고무패킹/택1/패킹/일반용/IH용/열판용*',
#  '린나이 스마트 가스보일러 R331-16MF (105.8㎡/상향식/기본설치비포함)',
#  '린나이 스마트 콘덴싱 보일러 RC35-37MF',
#  '린나이 컨벡션오븐 RCD-A32H',
#  '린나이/3구/가스렌지/고효율버너/전화구/과열방지센서/불꽃자동조절센서/고내구성/최고급/펄크리스탈상판/가스레인지/RTR-B3000',
#  '릴렉스테크 안마의자 RX-5800 /체형감지/SL프레임/온열기능',
#  '마그피아 착착자석글자퍼즐(한글) 유아교재/ 자석퍼즐 알파벳놀이 한글자석교구 자석숫자 유아자석교구 자',
#  '마이프랜드 엔틱실버메탈 선풍기 MF2214MS 미니선풍기',
#  '매장스피커/매장용스피커/카페스피커(E9B0347)',
#  '매킨토시 MA-7000',
#  '맥스퓨어 세디멘트필터 커피머신 커피점 제빙기 정수',
#  '머스타드 모아하우스 454g 머스터드',
#  '메가폰/휴대용메가폰/핸드메가폰/무선메가폰',
#  '메인 개별 복합스위치형 멀티탭 5구(1.5M,2.5M,4.5M) 전기절약형',
#  '면도기날 ESLT7N / ES-LT7N 파나소닉 면도기 모델에 사용됩니다',
#  '모니터오디오 NEW Gold 300 종,합',
#  '모토로라 FULL한글 디지털 무선전화기 C2001A',
#  '목걸이 타입 아이리버 S10 MP3',
#  '무료배송 U3585 USB 전원 미니 탁상용 선풍기-상하조절-저소음 4엽 날개-노트북 USB 선풍기-회색',
#  '무료배송 예스뷰티 휴대용 미니매직기 YB MINI MAGIC',
#  '무료배송/3L 발펌프',
#  '무료배송/코털 가위/코털정리기 코털제거기 코털면도',
#  '무료배송설치/BSN-2014/부성스노우스토리눈꽃제빙기',
#  '무배 [IB894] 명품 2채널 블루투스 스피커/포터블/AUX/블루투스 v4.1/3D 스테레오/미니/스마트폰 리모트 컨트롤',
#  '무선 전기주전자1.5L FK-0150 _생활용품_리빙_욕실_할',
#  '미니 요구르트 제조기 500ml 우유팩사용 요거트',
#  '미니 음이온 공기청정기 차량용 사무실용 가정용 USB',
#  '미니 트랜스 [ 승압기 / 110 - 220 ]',
#  '미니 핸디 사과선풍기 목걸이선풍기',
#  '미니샵 F19WF LG 트롬 19kg 세탁전용',
#  '미니케이블오거나이저 케이블정리용품 선정리 정리용품 케이블정리 케이블오거나이저',
#  '바라짜 바리오 그라인더/바리오W 그라인더/세라믹 그라인더/전동 그라인더/커피밀/전동밀/원두그라인더/커피그라인더/커피분쇄기/원두분쇄기/가정용그라인더/가정용전동밀/로스터기/핸드밀',
#  '바텔 D571MST 무선 전화기 4대 셋트 구삼성무선전화기',
#  '반죽기[360x470x660]KB108',
#  '버텍스 / 바이스 / 연마용 공구 / 클램핑 키트 / CK-104B',
#  '벽걸이TV거치대 LP12-44F (42~55인치 피봇설치형)',
#  '벽걸이티비설치 TV거치대 BLW-69F 60~100인치 삼성,엘지,중소/TV브라켓/TV거치대/아이엠로지텍 1666-4311',
#  '보쉬 GAS 14.4V/GAS 18V 전용 헤파필터/노즐/거치대',
#  '비스비 소니 NWZ-ZX1 쉴드필름 지문방지 액정보호필름(1 film) / SHIELD FILM ANTI GLARE FOR SONY NWZ-ZX1',
#  '빅마트 정품 스마트폰이어폰 RP-TCM105 통화기능 풍부',
#  '빅사이즈 집게겸용 USB 탁상용 선풍기 - 핑크/탁상용선풍기/여름/책상선풍기/집게/USB선풍기/휴대용선풍기',
#  '사은품증정 에어프라이어 3.2L 블렉 타이머 GT-522KAF',
#  '사파이어 벽걸형 히터 전기히터 벽걸이히터 sf-1600h 할로겐 타이머 좌우회전 전기스토브 난방가전',
#  '사파이어 절전형 미니 라디에이터 5핀 HJO-M05',
#  '산요/SANYO PLC-XU55 전용 프로젝터램프(정품베어램프)최저가판매',
#  '살라비 스팀팜(TS-01)/스팀다리미/미니다리미/핸디',
#  '삼성 AF15FVVH1WK 인버터 에어컨 1등급 에어콘 설치',
#  '삼성 POWERbot 로봇청소기 VR20H9052WW',
#  '삼성 공기청정기 호환용필터 1년분 HC-W101S HC-W103S',
#  '삼성 빌트인 전자레인지 RE-B23TST',
#  '삼성 청소기 호스/손잡이 없음 /사용모델:VC33K5110LD',
#  '삼성로봇청소기 VR20J9250UK/파워봇/에보니 쿠퍼ok',
#  '삼성전자 AF18K9970GFK (무풍냉방 에어컨/스텐드 단품)',
#  '삼성전자 MC324GAKCWQ 복합형 스마트오븐(화이트)',
#  '삼성전자 버튼형 세라믹 전자레인지 RE-C21KB',
#  '삼성정품 삼성 청소기 베기헤파 필터  / 사용모델:VC-B710W',
#  '삼성정품 삼성 청소기 스폰지필터와 틀세트/사용모델:VCC4760H',
#  '삼성정품 삼성 청소기 침구 브러쉬/사용모델:VC33H4010LY',
#  '삼성정품 진공 청소기 필터(헤파)/사용모델:VC-MCN704',
#  '삼원온스파 온돌마루온수',
#  '선풍기 안전망 고급형(먼지필터형)',
#  '선풍기걸이 브라켓 1개  선풍기벽걸이 벽걸이판 선풍기벽걸이판 벽걸이브라켓 벽걸이판 선풍기벽걸이 벽걸',
#  '선풍기날개 총모음/날개총집합/한일/신일/LG/삼성/14인치/16인치/선풍기커버/안전망',
#  '세라믹 원통형히터/SEB-250/가정용/거실/사무실/학원',
#  '세코 아우리카 포커스/커피머신/1544-2189',
#  '셰프라인 미니 전기오븐 컴팩트 그릴 베이킹 토스트',
#  '소니 ICF-P36 라디오 FM/AM 내장스피커 안테나',
#  '손잡이 아날로그 단파라디오/캠핑점사은품 캠핑장납품',
#  '슈어 PGA48-LC 다이나믹마이크/PGA-48',
#  '스마트센서 가스렌지/2구/가스레인지/RTR-20W01',
#  '스타리온 로터리히터 SH-R06SCH/13평형/음성지원/정품',
#  '스틸 4단 서류보관함/화일꽂이 문서보관 데스크정리함',
#  '신나라 무선 듀얼팬 미니 선풍기 고급형 작은선풍기',
#  '신일 15핀 라디에이터 SER-J3000CM / 15핀 히터 대형',
#  '신일 16 천정형 선풍기 (스위치없음) SIF-16CSM/신일/선풍기/여름',
#  '신일 45L 대용량 컨벡션 전기오븐기 SOV-S4500GR 오븐 신일오븐',
#  '신일 가스히터 SCG-1500WJ 휴대용 부탄가스 캠핑낚시',
#  '신일 국산 벽걸이선풍기 SIF-16WJK/40cm/3엽/3단풍속',
#  '신일 온풍 팬히터 SFH-904DMA 신일팬히터 가정용,업소',
#  '신일 천장용 선풍기 SIF-16CSH 16인치',
#  '신일 청소기 svc-wk1000 핸디+스틱 연장관 충전식 무선청소기 생활가전 국산 신일 싸이클론 노즐:틈새 바닥',
#  '신일 펠렛난로 SPH-N12000 /열풍기/펠릿히터/돈풍기/',
#  '신일/원통형/카본/전기히터/2800W/난로/SEH-2800GMK',
#  '신일무연통펠렛난로SPH-N12000신일정품2015년형/가정집/업소형/펠렛히터/난로/사무실/모델하우스/교회/성당/커피숍형/난방기기/순수',
#  '신일산업 SCG-940SP 휴대용가스히터/부탄가스/이동손잡이/안전망(왕세일)',
#  '신일산업 식품건조기 SFD-52RM',
#  '신일산업/벽걸이/벽걸이 선풍기/좌우회전/SIF-16WOH',
#  '아남 포터블카세트/라디오 카세트/A-33 /마이크내장/테이프녹음기 부모님',
#  '아이가다섯청소기_애니스 물걸레진공청소기+걸레4장',
#  '아이리버 D27 전자사전',
#  '아이리버 정품 칫솔살균기 TM-3700a',
#  '아임스21 디저트 스타(아이스크림 메이커) 디저트제조',
#  '아풍오닉스 고무장갑소독용/행주소독용 자외선 살균소독기 AP15',
#  '알텐바흐 스팀파워 전기다리미 브러쉬다리미 가정용전',
#  '압력펌프어댑터 dc24v/ad-24vdc/정수기부품',
#  '야마하 CRX-332 + 보스톤어쿠스틱스 A23 미니오디오 패키지',
#  '야마하 RX-S601 + 클립쉬 R-28F 5채널스피커',
#  '업소용인덕션/전기렌지',
#  '에코바로누리 천연가습기만들기4종 가습기만들기 가습',
#  '에코바로누리 천연가습기만들기4종 미니가습기 오일',
#  '엘지공기청정기필터/LA-M130SW/호환용필터1년사용분세트',
#  '엘지전자 MW235CW 2015년 신모델 전자레인지 23L 입체회전 이지클린',
#  '연우몰 GIGABYTE GA-H110N 듀러블에디션 제이씨현 입금확인 즉시출고 배송',
#  '영업용/산업용  건.습식 청소기  범퍼형 KS-500 보흥',
#  '예스뷰티 라운드형 온도조절 고데기 YB-6300R/볼륨/매직기/웨이브/물결/고대기/물결펌/볼륨매직기/전문가용',
#  '예스뷰티 아이롱 컬러 웨이브 고데기 고대기 봉고데기 미용기기 미용기구 헤어미용기기',
#  '오빠네사진관 - FOMEX(正品) E400 SS-A세트/웨딩촬영조명/리허서촬영조명/신부촬영조명/결혼사진조명/추천',
#  '와피데일 Diamond 9.1 북셀프스피커',
#  '우성금속 전기국끓이기 전기국통 보온국통 30호(30L)',
#  '웅진공기청정기필터AP-1201AH/AP-1004AH/AP-1005AH/AP-1007AH/AP-1503CH/AP-1008BH/AP-1008CH/AP-1008DH/APM-1011YH/',
#  '워터픽 WP-70K 클래식 구강세정기 잇몸관리 사은품',
#  '원두커피머신임대/렌 탈(금정구/남구/동구/동래구)',
#  '원봉 WFP-7340L 1년세트 정수기필터호환 프리미엄',
#  '원봉워터피아 WFP-860 호환 정수기필터 한방향8개',
#  '원적외선 고효율 에어렉스 VG-30 125㎡/37형 열풍기',
#  '원적외선 조리기 바이오하이퍼그릴',
#  '원피스 월드콜렉터블 피규어 vol.30 [단품-스팬 다인]',
#  '월풀 양문형 냉장고 5WRS25FDBF (708L)',
#  '월풀/정품 ACT312/BL 하이라이트/1구 전기렌인지 w',
#  '위니아 만도 WDG-N09 이온수기 마 D2 필터',
#  '위니아만도 PAS-152DP 2012신형/스탠드/강력냉방/카본탈취필터(왕세일)',
#  '위닉스 냉온수기 원봉냉온수기 정수기 하프형/스탠드',
#  '위성계측기/디지털계측기/HD/초소형/USB2.0지원',
#  '유닉스 UB-A9503 뷰티 클렌징 브러쉬',
#  '유닉스 전기/충전 겸용 유무선 이발기 UNT-A8990',
#  '으뜸이 /고체산소(리빙/오토/스터디)  /산소발생기 무소음+전기코드No /공기청정기 /공기정화기 황사 새집증후군',
#  '이동식앰프/이동식엠프/JEZ1298',
#  '이소닉//계산기녹음기//VR-CA02 정품/최장(연속3일)/장시간녹음기/비밀녹음기/녹음/회의녹음/강의녹음/보이스레코더',
#  '이스타 디지털 스텐 2중 무선포트 1.2L',
#  '이태리 명품 가전 로쏘울프 요구르트제조기/청국장제조기/요거트제조기/요거트메이커/요구르트메이커/청국장만들기',
#  '인비오 프리미엄 포터블 DVD플레이어 9  인 TV출력지원 코드프리 5시간재생 영화 어학학습용 디빅스 MP3 CD 2014년 최신형 신제품 포타블 DVDP',
#  '자외선 살균 건조 소독기 AP200',
#  '저소음 ？ ㅏ？ 진공포장기 세이버락 진공롤팩 파우치',
#  '전기가 필요없는 요거트랑 요거트 메이커 요플레 요구르트제조기 간식 마니앤샵',
#  '정수기부품 숫나사형꼭지 안전코크 (냉수/온수)1쌍',
#  '정수기부품 정수기받침대',
#  '정전식 터치펜 LG G2 용 악세사리터치팬 정전식터치펜',
#  '정품 삼성 청소기 물걸레 브러쉬/사용모델:VC-MB755Z',
#  '제너스 JNF-4515W 40cm 벽걸이 선풍기 벽걸이선풍기 선풍기 벽걸이형선풍기 선풍기벽걸이 제너스선풍기',
#  '젠하이저 HD477 HD497 HD212 EH250 EH350 호환 케이블',
#  '조아스 충전식면도기JS-5717 이미용가전 세안 욕실용',
#  '조아스전기면도기 JS-5717 조아스면도기/ 남성용전기면도기 전기면도기추천 남자전기면도기 남성전기면도기',
#  '진공청소기 DS5600 (1400w) KARCHER-카처청소기',
#  '천연루비반지/0.6ct/광택칼라굳/14k골드/쎄일',
#  '천우 CWP-2153H 전체세트 정수기필터호환 실속형',
#  '천장형 전기온풍기 YH-010P/2~3평/7.3㎡/1kw',
#  '청색 돼지저금통 (자이언트 동전 저축 저금 지폐 다용',
#  '카이스 화장품냉장고 9리터  이슬맺힘방지 저소음 자동온도조절 KC-120S',
#  '카즈 USB가습기(전구형)/인테리어가습기/미니가습기',
#  '카처 MV4 프리미엄 건습식청소기/업소용 청소기/카쳐/진공청소기',
#  '카타 2단 전기찜기 웰빙찜기 쿠커 ESC-361',
#  '칼도마살균건조소독기[600x600x1550]SK-1550U가격상담문의',
#  '캐리어 냉난방기 CX-185F /기본설치O/기본배관 8M',
#  '커피메이커 700ml 홍차 녹차 허브차 커피용품 허브차',
#  '켄우드 ST-60A 여행용 유선 스팀다리미 110-220V 겸용 테프론코팅 순간스팀분사/미니스팀다리미/정품',
#  '코드프리 DVD 업스케일 HDMI / 지능형알고리즘CINENAPLUS / USB미디어단자 / Y7U7AS1/DivX ULTRA/ MP3 재생 DVP/리모트컨트롤/CODE FREE/',
#  '코드프리(미국 일본...) DVD플레이어 트레이형 DivX재생 돌비디지털 USB재생 녹음 /저전력소비/1SSA-1/고주파진동 렌즈먼지제거/콤포넌트/콤포지트',
#  '코멕스 CM-16HL 할로겐 16형 벽걸이히터/좌우회전 /16',
#  '코원 MP3 D3 DMB[32GB]+CE1정품이어폰+액정보호필름/MP4/PMP/WIFI/인터넷/블루투스/안드로이드/아몰레드전자사전',
#  '코원 PMP 스터디프로[32GB]+정품필름/Full-HD/학습전용/악세사리95%할인/MP3/MP4/전자사전/태블릿PC/스피커탑재/보이스레코더/완벽인강/G7/Q7/아이패드/에어2/미',
#  '쿠도스타일 쿠도스 Super 10',
#  '쿠쿠 냉온정수기 큐브정수기 CP-F602HW 월 19900원',
#  '쿠쿠 전기밥솥 14 17 30인용 밥솥 전기밥통 취사 보온밥통 보온밥솥 대웅 맘쿡',
#  '쿠쿠공식대리점 살균정수기 직수형CP-LS011B월35900원',
#  '쿠쿠패킹 2중모션 분리형커버패킹 CCP-DH06 압력패킹',
#  '키친아트 전기밥솥 미니미니 전기밥솥 (1인용) 보온도시락 사이즈 휴대성 간편성',
#  '키친에이드 다기능 스탠드 믹서 반죽기 5KSM150PSE(WH)',
#  '키친에이드정품/K5SS/반죽기/거품기/제과제빵기1-10단',
#  '키친플라워 67cm KEP-KS1700WG 전팬 전기팬 피자팬 전기그릴 대용량그릴',
#  '키친플라워 만능 피자팬 KEP-NB460',
#  '키친플라워 미니믹서기 KF-HM500(컵5개)',
#  '타이거킹 TK-240ID/간접열풍히터/난로/열풍기/기름히터/석유난로/동일정밀/유해가스배출구/외부온도감지/희망온도조절/3중안전장치/기어드펌프/농가/축사/공장/창고/전국배송가능/세금계',
#  '타이거킹 열풍건조기 ZF-120K / 등유열풍기 /공업난로',
#  '태진노래반주기 노래방기기 가라오케/해외사용가능/최다곡수록/육성메들리수록',
#  '테팔 에어프라이어/액티프라이/FZ205089/엑티프라이어/튀김기',
#  '토요토미 옴니230SE+정품가방+상단망 캠핑/석유/난로',
#  '투인원 부채선풍기 건전지포함 미니선풍기 손선풍기 부채 휴대용선풍기 미니선풍기 휴대용선풍기 부채 생활가전 손선풍기',
#  '트라이던트 16형 선풍기 스탠드형 선풍기 TD-1610WS',
#  '트윈스 LG 트롬 FR24D7MQNZ 드럼세탁기 세탁+건조',
#  '티맥스 퍼팅가이드 집중력 방향성 향상 퍼팅연습매트 골프퍼팅매트 퍼터연습',
#  '파나소닉 ES-2113 눈썹 정리기 / 두가지 칼날 / 건전지 전용 / 휴대용 눈썹 정리기 / 건전지 증정',
#  '파나소닉정품 귀걸이형이어폰 RP-HS46 풍부한사운드 스테레오 스마트폰 CDP MP3',
#  '파세코 빌트인3구 가스레인지[다원]PGC-B360RH/가스쿡탑/가스렌지/빌트인가스렌지/PGC-B360R 신형/안전센서',
#  '폐수저항피팅 FR-600 1/41/4 600ml',
#  '프리미엄 연수기 피팅3호 아파트 샤워기 세면기 세탁',
#  '필립스 데일리 미니 블렌더 HR2876 00  350W',
#  '필립스)코털제거기 NT9110/코털정리기+눈썹정리기/생활방수/정밀밀착컷팅/소프트그립코팅/건전지식',
#  '필립스정품NEW NT-3355/코털눈썹정리/미국직수입/',
#  '하이라이트 BSW(BS-1320-HL)',
#  '하츠/NCH-90S/뉴침니/렌지후드/침니후드/데코후드/알루미늄필터/리빙앤피플',
#  '한빛 근적외선스탠드히터 HV-1080(1100W) / 전기히터',
#  '한빛 전기히터 나노카본히터모음 카본히터 원통형히터',
#  '한솔 강력 대형 산업용 냉풍기 HNK-F2000 기화냉각방',
#  '한솔 대용량파워 에어쿨러HNK-F2000산업용 공업용 냉풍기 순수',
#  '한솔 펠렛난로 HS-N250  돈풍기/화목난로/화목보일러/펠렛히터/목재난로/목재돈풍기/펠릿히터/석유난로/공장난로/업소용난로/공장난방기기/업소용난방기기 DK',
#  '한솔일렉트로닉스 돈풍기 HEH-130/석유히터/난로/온풍',
#  '한솔펠렛난로/HS-DP13006F/HS-DP16006F/HS-DP21006F/HS-DP25006F/13000Kcal~250000kcal/온풍/고급형/비용절감/돈펠',
#  '한일꽃잠/ 투컬러 온열매트 프리미엄 싱글/ 전기장판',
#  '한일의료기 삼단방석 극세사 전기방석/매트/카페트/전기카페트/전기매트/겨울매트/온열카페트/한일의료기/온수매트/옥매트/거실용/침대용/전기장판',
#  '한일테크 판넬용 /500VA/단상/단권/복권/각종전압 제작가능(단) 트랜스 변압기',
#  '한일트랜스/3K/트랜스/변압기/승압기/다운기',
#  '한일파테크 드라이기/전문가용/업소용 PD-N2355WS',
#  '해피코리아/미니솥 140 (2인용)/무쇠가마/가마솥/주물/화로/',
#  '헤어드라이기/원적외선/옥풍/드라이/두피/모발건강/옥',
#  '헤어컬/PH-010/파테크헤어컬/브러쉬2종/3단스위치/유닉스/바비리스/한일전자/파테크/신상',
#  '헬스케어dr-usb 닥터유에스비 공기청정기 차량용 항균 탈취 생활악취 휴대가용이 미니공기청정',
#  '헵시바 HSC-3600 /신제품/에어렉스/대용량/실외기없는 이동식에어컨/집중냉방가능/에어콘/냉방기/공업용/헵시바/코끼리/산업현장/주차장/공장/휴게소/식당 !! 퀵배송가능/세금계산서',
#  '홈빙 초간단 요구르트제조기2종',
#  '화니 듀얼회전스팀청소기 HSV-5000.S[물분사 + 스팀]/회전청소기/양회전패드/극세사걸레/현진포커스',
#  '환풍기 SIV-259GC(설치규격300(㎜)신일산업/환풍기/수',
#  '환풍기/범용/국내산/천장/벽면/용/저소음/사무실/소형',
#  '휘센 FQ181MK2WM/기본설치포함/스탠드에어컨/냉방58㎡',
#  '휴대용 USB 카세트 플레이어실버 -카세트녹음편집 가',
#  '휴대용워크맨 MS3000 카세트플레이 녹음 스피커내장 FMAM라디오 이어폰포함 이어폰카세트 간편카세트 FM카',
#  '휴롬 원액기 HB-RBF08 [드럼용량:350ml / 저속착즙방식 / 간이세척 가능 / 주스캡',
#  '히브리서 Live고급성경/듣는찬송가 듣는성경/복음 병원/요양원/ujtm550-yb6-ei2 /창세기 효도선물/복음성가 /풍부한사운드/로마서 디지털성경 복음성가 말씀성경 병원 요양원',
#  ...]

# %%
from konlpy.tag import Kkma
# kkma = Kkma()
# strlist = []
# for data in tmp_list:
#     nouns=kkma.nouns(data)
#     nstr = ""
#     for i in range(0,len(nouns)):
#         nstr += nouns[i] + " "
#     strlist.append(nstr)

# %%
def kkmalist(x_text_list):
    tmp_list = list(map(lambda i:i[1],x_text_list))
    kkma = Kkma()
    strlist = []
    for data in tmp_list:
        nouns=kkma.nouns(data)
        nstr = ""
        for i in range(0,len(nouns)):
            nstr += nouns[i] + " "
        strlist.append(nstr)
    return strlist

#kkmalist(x_text_list)

# %%
from sklearn.model_selection import train_test_split

vectorizer = CountVectorizer()
x_noun_list = kkmalist(x_text_list)
x_list = vectorizer.fit_transform(x_noun_list)
y_list = [y_name_id_dict[x] for x in y_text_list]

# %% [markdown]
# ### train test 분리하는 방법

# %%
print(x_text_list[2])
# Out:
# ('1546650266', '(AGCRIP 웨빙 포켓조끼 빅사이즈 조끼 MK321_324 아웃')

# %%
X_train, X_test , y_train, y_test = train_test_split(x_text_list, y_list, test_size=0.2, random_state=42)

# %%
# print(vectorizer.transform(list(map(lambda i : i[1],X_train))))

# %% [markdown]
# ### 몇개의 파라미터로 간단히 테스트 하는 방법

# %%
for c in [1,5,10]:
    clf = LinearSVC(C=c)
    X_train_text = kkmalist(X_train)
    clf.fit(vectorizer.transform(X_train_text), y_train)
    #print (c,clf.score(vectorizer.transform(map(lambda i : i[1],X_test)), y_test))

# %% [markdown]
# ### 최적의 파라미터를 알아서 다 해보고, n-fold cross validation까지 해주는 방법 - GridSearchCV

# %%
svc_param = np.logspace(-1,1,4)

# %%
gsvc = GridSearchCV(LinearSVC(), param_grid= {'C': svc_param}, cv = 5, n_jobs = 4)

# %%
gsvc.fit(vectorizer.transform(x_noun_list), y_list)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#        fit_params={}, iid=True, n_jobs=4,
#        param_grid={'C': array([  0.1    ,   0.46416,   2.15443,  10.     ])},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
print(gsvc.best_score_, gsvc.best_params_)
# Out:
# 0.6804705882352942 {'C': 0.10000000000000001}

# %% [markdown]
# #### 평가 데이터에 대해서 분류를 한 후에  평가 서버에 분류 결과 전송

# %%
eval_x_text_list = []
with open("soma8_test_data.dat",encoding=enc) as fin:
    for line in fin.readlines():
        info = json.loads(line.strip())
        eval_x_text_list.append((info['pid'],info['name']))

# %%
pred_list = clf.predict(vectorizer.transform(map(lambda i : i[1],eval_x_text_list)))

# %%
pred_list = gsvc.predict(vectorizer.transform(kkmalist(eval_x_text_list)))

# %%
# print (pred_list.tolist())

# %%
import requests
name='이윤성'
nickname='easy_to_find'
mode='test'
param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
         'name':name,'nickname':nickname,'mode':mode}
d = requests.post('http://eval.buzzni.net:20001/eval',data=param)

print (d.json())
# Out:
# {'msg': 'If you pull docker image before 2017-09-27 21:30,  pull your docker image again.', 'precision': 0.7623839009287926}

# %% [markdown]
# #### eval 데이터에 대해서 분류를 한 후에  평가 서버에 분류 결과 전송
#  * 실제 여기서 나온 점수로 채점을 한다.

# %%
eval_x_text_list = []
with open("soma8_eval_data.dat",encoding=enc) as fin:
    for line in fin.readlines():
        info = json.loads(line.strip())
        eval_x_text_list.append((info['pid'],info['name']))
pred_list = gsvc.predict(vectorizer.transform(kkmalist(eval_x_text_list)))
name='이윤성'
nickname='easy_to_find'
mode='eval'
param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
         'name':name,'nickname':nickname,'mode':mode}
d = requests.post('http://eval.buzzni.net:20001/eval',data=param)

print (d.json())
# Out:
# {'msg': 'success', 'precision': ''}

# %% [markdown]
# ### CNN 으로 추출한 이미지 데이터 사용하기
#  * keras mobilenet 으로 추출한 데이터, 이 데이터를 아래처럼 읽어서 사용 가능함
#  * 더 성능이 높은 모델로 이미지 피쳐를 추출하면 성능 향상 가능함

# %%
pid_img_feature_dict = {}
with open("refined_category_dataset.img_feature.dat") as fin:
    for idx,line in enumerate(fin):
        if idx%100 == 0:
            print(idx)
        pid, img_feature_str = line.strip().split(" ")
        img_feature = (np.asarray(list(map(lambda i : float(i),img_feature_str.split(",")))))
        pid_img_feature_dict[pid] = img_feature
#         print (line)
#         break

# %%
from scipy import sparse

# %%
img_feature_list = []
for pid, name in X_train:
#     print(pid, name)
    if pid in pid_img_feature_dict:
        img_feature_list.append(pid_img_feature_dict[pid])
#         print (len(pid_img_feature_dict[pid]),type(pid_img_feature_dict[pid]))
#         break
    else:
        img_feature_list.append(np.zeros(1000))
#     break

# %%
img_feature_test_list = []
for pid, name in X_test:
    if pid in pid_img_feature_dict:
        img_feature_test_list.append(pid_img_feature_dict[pid])
    else:
        img_feature_test_list.append(np.zeros(1000))

# %%
print(len(img_feature_list))

# %% [markdown]
# #### 아래 부분은 text feature 와 이미지 feature 를 합쳐서 feature 를 만드는 부분이다. 이 부분에 대해서는 각자 한번 합치는 방법을 찾아 보면 된다.

# %%
# concat_x_list = func((vectorizer.transform(map(lambda i : i[1],X_train)), img_feature_list))
#concat_test_x_list = func((vectorizer.transform(map(lambda i : i[1],X_test)), img_feature_test_list))

# %%
for c in [1]:
    clf2 = LinearSVC(C=c)
    clf2.fit(concat_x_list, y_train)
    print (c,clf2.score(concat_test_x_list, y_test))

# %%
del pid_img_feature_dict

# %% [markdown]
# ### CNN 피쳐를 추가 해서 분류후 평가 서버에 분류 결과를 전송

# %%
pid_img_feature_dict = {}
with open("/workspace/resources/refined_category_dataset.img_feature.eval.dat") as fin:
    for idx,line in enumerate(fin):
        if idx%100 == 0:
            print(idx)
        pid, img_feature_str = line.strip().split(" ")
        img_feature = (np.asarray(list(map(lambda i : float(i),img_feature_str.split(",")))))
        pid_img_feature_dict[pid] = img_feature
#         print (line)
#         break

# %%
test_x_text_list = []
with open("soma8_test_data.dat",encoding=enc) as fin:
    for line in fin.readlines():
        info = json.loads(line.strip())
        test_x_text_list.append((info['pid'],info['name']))

# pred_list = clf.predict(vectorizer.transform(map(lambda i : i[1],eval_x_text_list)))

# %%
img_feature_eval_list = []

# %%
for pid, name in test_x_text_list:
    if pid in pid_img_feature_dict:
        img_feature_eval_list.append(pid_img_feature_dict[pid])
    else:
        img_feature_eval_list.append(np.zeros(1000))

# %%
print (len(img_feature_eval_list), len(eval_x_text_list))

# %%
x_feature_list = vectorizer.transform(map(lambda i : i[1],test_x_text_list))

# %% [markdown]
# #### 2개 feature 를 합치는 방법 찾아보기

# %%
concat_test_x_list = sparse.hstack((x_feature_list, img_feature_eval_list),format='csr')

# %%
pred_list = clf2.predict(concat_test_x_list)

# %%
import requests
name='test0'
nickname='test0_textimage_svm'
mode='test'
param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
         'name':name,'nickname':nickname,'mode':mode}
d = requests.post('http://eval.buzzni.net:20001/eval',data=param)
print (d.json())

# %%
eval_x_text_list = []
with open("soma8_eval_data.dat",encoding=enc) as fin:
    for line in fin.readlines():
        info = json.loads(line.strip())
        eval_x_text_list.append((info['pid'],info['name']))

# pred_list = clf.predict(vectorizer.transform(map(lambda i : i[1],eval_x_text_list)))

# %%
img_feature_eval_list = []
for pid, name in eval_x_text_list:
    if pid in pid_img_feature_dict:
        img_feature_eval_list.append(pid_img_feature_dict[pid])
    else:
        img_feature_eval_list.append(np.zeros(1000))

# %%
x_feature_list = vectorizer.transform(map(lambda i : i[1],eval_x_text_list))

# %%
concat_eval_x_list = sparse.hstack((x_feature_list, img_feature_eval_list),format='csr')

# %%
pred_list = clf2.predict(concat_eval_x_list)

# %%
import requests
name='test0'
nickname='test0_textimage_svm'
mode='eval'
param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
         'name':name,'nickname':nickname,'mode':mode}
d = requests.post('http://eval.buzzni.net:20001/eval',data=param)
print (d.json())
